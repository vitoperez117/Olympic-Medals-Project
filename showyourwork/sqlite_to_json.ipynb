# %%
# Ignore SQLITE warnings related to Decimal numbers in the Chinook database
import warnings
warnings.filterwarnings('ignore')

# %%
# Import Dependencies
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine
from sqlalchemy import func
from sqlalchemy import or_
import pandas as pd

# %%
# Create an engine for the chinook.sqlite database
engine = create_engine("sqlite:///stackedmedals.sqlite", echo=False)

# %%
# Reflect Database into ORM classes
Base = automap_base()
Base.prepare(engine, reflect=True)
Base.classes.keys()
# Out:
# ['dummy_table', 'joyce']

# %%
# Save a reference to the invoices table as `Invoices`
olympics = Base.classes.joyce

# %%
# Create a database session object
session = Session(engine)

# %%
#inital query
masterPull = session.query(olympics.ID, olympics.name, olympics.year, olympics.gold, olympics.silver,olympics.bronze).all()

# %%
finalPull = []
for i in masterPull:
    finalPull.append({"id": i[0], "name": i[1], "year": i[2], "gold": i[3], "silver": i[4], "bronze":i[5]})

# %%
finalPull
# Out:
# [{'id': 0,
#   'name': 'A North American Team',
#   'year': 1900,
#   'gold': 0,
#   'silver': 0,
#   'bronze': 4},
#  {'id': 1,
#   'name': 'Afghanistan',
#   'year': 2008,
#   'gold': 0,
#   'silver': 0,
#   'bronze': 1},
#  {'id': 2,
#   'name': 'Afghanistan',
#   'year': 2012,
#   'gold': 0,
#   'silver': 0,
#   'bronze': 1},
#  {'id': 3,
#   'name': 'Algeria',
#   'year': 1984,
#   'gold': 0,
#   'silver': 0,
#   'bronze': 2},
#  {'id': 4,
#   'name': 'Algeria',
#   'year': 1992,
#   'gold': 1,
#   'silver': 0,
#   'bronze': 1},
#  {'id': 5,
#   'name': 'Algeria',
#   'year': 1996,
#   'gold': 2,
#   'silver': 0,
#   'bronze': 1},
#  {'id': 6,
#   'name': 'Algeria',
#   'year': 2000,
#   'gold': 1,
#   'silver': 1,
#   'bronze': 3},
#  {'id': 7,
#   'name': 'Algeria',
#   'year': 2008,
#   'gold': 0,
#   'silver': 1,
#   'bronze': 1},
#  {'id': 8,
#   'name': 'Algeria',
#   'year': 2012,
#   'gold': 1,
#   'silver': 0,
#   'bronze': 0},
#  {'id': 9,
#   'name': 'Algeria',
#   'year': 2016,
#   'gold': 0,
#   'silver': 2,
#   'bronze': 0},
#  {'id': 10,
#   'name': 'Ali-Baba II',
#   'year': 1948,
#   'gold': 0,
#   'silver': 0,
#   'bronze': 5},
#  {'id': 11,
#   'name': 'Amateur Athletic Association',
#   'year': 1900,
#   'gold': 5,
#   'silver': 0,
#   'bronze': 0},
#  {'id': 12,
#   'name': 'Amstel Amsterdam',
#   'year': 1908,
#   'gold': 0,
#   'silver': 0,
#   'bronze': 4},
#  {'id': 13,
#   'name': 'Ancora',
#   'year': 1920,
#   'gold': 4,
#   'silver': 0,
#   'bronze': 0},
#  {'id': 14,
#   'name': 'Angelita',
#   'year': 1932,
#   'gold': 12,
#   'silver': 0,
#   'bronze': 0},
#  {'id': 15,
#   'name': 'Antwerpia V',
#   'year': 1920,
#   'gold': 0,
#   'silver': 0,
#   'bronze': 5},
#  {'id': 16,
#   'name': 'Aphrodite',
#   'year': 1964,
#   'gold': 0,
#   'silver': 0,
#   'bronze': 3},
#  {'id': 17,
#   'name': 'Argentina',
#   'year': 1924,
#   'gold': 5,
#   'silver': 3,
#   'bronze': 2},
#  {'id': 18,
#   'name': 'Argentina',
#   'year': 1928,
#   'gold': 3,
#   'silver': 18,
#   'bronze': 5},
#  {'id': 19,
#   'name': 'Argentina',
#   'year': 1932,
#   'gold': 3,
#   'silver': 1,
#   'bronze': 0},
#  {'id': 20,
#   'name': 'Argentina',
#   'year': 1936,
#   'gold': 5,
#   'silver': 2,
#   'bronze': 4},
#  {'id': 21,
#   'name': 'Argentina',
#   'year': 1948,
#   'gold': 3,
#   'silver': 2,
#   'bronze': 1},
#  {'id': 22,
#   'name': 'Argentina',
#   'year': 1952,
#   'gold': 2,
#   'silver': 2,
#   'bronze': 2},
#  {'id': 23,
#   'name': 'Argentina',
#   'year': 1956,
#   'gold': 0,
#   'silver': 1,
#   'bronze': 1},
#  {'id': 24,
#   'name': 'Argentina',
#   'year': 1960,
#   'gold': 0,
#   'silver': 0,
#   'bronze': 1},
#  {'id': 25,
#   'name': 'Argentina',
#   'year': 1964,
#   'gold': 0,
#   'silver': 1,
#   'bronze': 0},
#  {'id': 26,
#   'name': 'Argentina',
#   'year': 1968,
#   'gold': 0,
#   'silver': 0,
#   'bronze': 2},
#  {'id': 27,
#   'name': 'Argentina',
#   'year': 1972,
#   'gold': 0,
#   'silver': 1,
#   'bronze': 0},
#  {'id': 28,
#   'name': 'Argentina',
#   'year': 1988,
#   'gold': 0,
#   'silver': 1,
#   'bronze': 12},
#  {'id': 29,
#   'name': 'Argentina',
#   'year': 1992,
#   'gold': 0,
#   'silver': 0,
#   'bronze': 2},
#  {'id': 30,
#   'name': 'Argentina',
#   'year': 1996,
#   'gold': 0,
#   'silver': 19,
#   'bronze': 1},
#  {'id': 31,
#   'name': 'Argentina',
#   'year': 2000,
#   'gold': 0,
#   'silver': 17,
#   'bronze': 3},
#  {'id': 32,
#   'name': 'Argentina',
#   'year': 2004,
#   'gold': 28,
#   'silver': 0,
#   'bronze': 21},
#  {'id': 33,
#   'name': 'Argentina',
#   'year': 2008,
#   'gold': 20,
#   'silver': 0,
#   'bronze': 31},
#  {'id': 34,
#   'name': 'Argentina',
#   'year': 2012,
#   'gold': 1,
#   'silver': 15,
#   'bronze': 3},
#  {'id': 35,
#   'name': 'Argentina',
#   'year': 2016,
#   'gold': 21,
#   'silver': 1,
#   'bronze': 0},
#  {'id': 36,
#   'name': 'Argonaut Rowing Club',
#   'year': 1908,
#   'gold': 0,
#   'silver': 0,
#   'bronze': 6},
#  {'id': 37,
#   'name': 'Armenia',
#   'year': 1996,
#   'gold': 1,
#   'silver': 1,
#   'bronze': 0},
#  {'id': 38,
#   'name': 'Armenia',
#   'year': 2000,
#   'gold': 0,
#   'silver': 0,
#   'bronze': 1},
#  {'id': 39,
#   'name': 'Armenia',
#   'year': 2008,
#   'gold': 0,
#   'silver': 0,
#   'bronze': 6},
#  {'id': 40,
#   'name': 'Armenia',
#   'year': 2012,
#   'gold': 0,
#   'silver': 1,
#   'bronze': 2},
#  {'id': 41,
#   'name': 'Armenia',
#   'year': 2016,
#   'gold': 1,
#   'silver': 3,
#   'bronze': 0},
#  {'id': 42,
#   'name': 'Aschenbrodel',
#   'year': 1900,
#   'gold': 4,
#   'silver': 4,
#   'bronze': 0},
#  {'id': 43,
#   'name': 'Atalanta Boat Club-1',
#   'year': 1904,
#   'gold': 2,
#   'silver': 0,
#   'bronze': 0},
#  {'id': 44,
#   'name': 'Atalanta Boat Club-2',
#   'year': 1904,
#   'gold': 0,
#   'silver': 2,
#   'bronze': 0},
#  {'id': 45,
#   'name': 'Atlanta',
#   'year': 1920,
#   'gold': 9,
#   'silver': 0,
#   'bronze': 0},
#  {'id': 46,
#   'name': 'Australasia',
#   'year': 1908,
#   'gold': 15,
#   'silver': 2,
#   'bronze': 2},
#  {'id': 47,
#   'name': 'Australasia',
#   'year': 1912,
#   'gold': 5,
#   'silver': 2,
#   'bronze': 3},
#  {'id': 48,
#   'name': 'Australia',
#   'year': 1896,
#   'gold': 2,
#   'silver': 0,
#   'bronze': 0},
#  {'id': 49,
#   'name': 'Australia',
#   'year': 1900,
#   'gold': 2,
#   'silver': 0,
#   'bronze': 3},
#  {'id': 50,
#   'name': 'Australia',
#   'year': 1904,
#   'gold': 0,
#   'silver': 3,
#   'bronze': 1},
#  {'id': 51,
#   'name': 'Australia',
#   'year': 1906,
#   'gold': 0,
#   'silver': 0,
#   'bronze': 3},
#  {'id': 52,
#   'name': 'Australia',
#   'year': 1920,
#   'gold': 0,
#   'silver': 6,
#   'bronze': 1},
#  {'id': 53,
#   'name': 'Australia',
#   'year': 1924,
#   'gold': 4,
#   'silver': 5,
#   'bronze': 2},
#  {'id': 54,
#   'name': 'Australia',
#   'year': 1928,
#   'gold': 1,
#   'silver': 2,
#   'bronze': 1},
#  {'id': 55,
#   'name': 'Australia',
#   'year': 1932,
#   'gold': 3,
#   'silver': 1,
#   'bronze': 1},
#  {'id': 56,
#   'name': 'Australia',
#   'year': 1936,
#   'gold': 0,
#   'silver': 0,
#   'bronze': 1},
#  {'id': 57,
#   'name': 'Australia',
#   'year': 1948,
#   'gold': 2,
#   'silver': 9,
#   'bronze': 5},
#  {'id': 58,
#   'name': 'Australia',
#   'year': 1952,
#   'gold': 7,
#   'silver': 2,
#   'bronze': 11},
#  {'id': 59,
#   'name': 'Australia',
#   'year': 1956,
#   'gold': 28,
#   'silver': 11,
#   'bronze': 23},
#  {'id': 60,
#   'name': 'Australia',
#   'year': 1960,
#   'gold': 11,
#   'silver': 24,
#   'bronze': 11},
#  {'id': 61,
#   'name': 'Australia',
#   'year': 1964,
#   'gold': 5,
#   'silver': 6,
#   'bronze': 30},
#  {'id': 62,
#   'name': 'Australia',
#   'year': 1968,
#   'gold': 5,
#   'silver': 35,
#   'bronze': 11},
#  {'id': 63,
#   'name': 'Australia',
#   'year': 1972,
#   'gold': 11,
#   'silver': 7,
#   'bronze': 2},
#  {'id': 64,
#   'name': 'Australia',
#   'year': 1976,
#   'gold': 0,
#   'silver': 15,
#   'bronze': 8},
#  {'id': 65,
#   'name': 'Australia',
#   'year': 1980,
#   'gold': 6,
#   'silver': 2,
#   'bronze': 5},
#  {'id': 66,
#   'name': 'Australia',
#   'year': 1984,
#   'gold': 7,
#   'silver': 14,
#   'bronze': 31},
#  {'id': 67,
#   'name': 'Australia',
#   'year': 1988,
#   'gold': 18,
#   'silver': 6,
#   'bronze': 11},
#  {'id': 68,
#   'name': 'Australia',
#   'year': 1992,
#   'gold': 14,
#   'silver': 27,
#   'bronze': 16},
#  {'id': 69,
#   'name': 'Australia',
#   'year': 1994,
#   'gold': 0,
#   'silver': 0,
#   'bronze': 4},
#  {'id': 70,
#   'name': 'Australia',
#   'year': 1996,
#   'gold': 32,
#   'silver': 16,
#   'bronze': 82},
#  {'id': 71,
#   'name': 'Australia',
#   'year': 1998,
#   'gold': 0,
#   'silver': 0,
#   'bronze': 1},
#  {'id': 72,
#   'name': 'Australia',
#   'year': 2000,
#   'gold': 58,
#   'silver': 69,
#   'bronze': 54},
#  {'id': 73,
#   'name': 'Australia',
#   'year': 2002,
#   'gold': 2,
#   'silver': 0,
#   'bronze': 0},
#  {'id': 74,
#   'name': 'Australia',
#   'year': 2004,
#   'gold': 49,
#   'silver': 77,
#   'bronze': 31},
#  {'id': 75,
#   'name': 'Australia',
#   'year': 2006,
#   'gold': 1,
#   'silver': 0,
#   'bronze': 1},
#  {'id': 76,
#   'name': 'Australia',
#   'year': 2008,
#   'gold': 31,
#   'silver': 42,
#   'bronze': 76},
#  {'id': 77,
#   'name': 'Australia',
#   'year': 2010,
#   'gold': 2,
#   'silver': 1,
#   'bronze': 0},
#  {'id': 78,
#   'name': 'Australia',
#   'year': 2012,
#   'gold': 18,
#   'silver': 37,
#   'bronze': 59},
#  {'id': 79,
#   'name': 'Australia',
#   'year': 2014,
#   'gold': 0,
#   'silver': 2,
#   'bronze': 1},
#  {'id': 80,
#   'name': 'Australia',
#   'year': 2016,
#   'gold': 23,
#   'silver': 34,
#   'bronze': 25},
#  {'id': 81,
#   'name': 'Australia-1',
#   'year': 1996,
#   'gold': 0,
#   'silver': 0,
#   'bronze': 2},
#  {'id': 82,
#   'name': 'Australia-1',
#   'year': 2000,
#   'gold': 2,
#   'silver': 0,
#   'bronze': 0},
#  {'id': 83,
#   'name': 'Australia/Great Britain',
#   'year': 1896,
#   'gold': 0,
#   'silver': 0,
#   'bronze': 2},
#  {'id': 84,
#   'name': 'Austria',
#   'year': 1896,
#   'gold': 2,
#   'silver': 1,
#   'bronze': 2},
#  {'id': 85,
#   'name': 'Austria',
#   'year': 1900,
#   'gold': 0,
#   'silver': 3,
#   'bronze': 3},
#  {'id': 86,
#   'name': 'Austria',
#   'year': 1904,
#   'gold': 1,
#   'silver': 1,
#   'bronze': 1},
#  {'id': 87,
#   'name': 'Austria',
#   'year': 1906,
#   'gold': 3,
#   'silver': 3,
#   'bronze': 3},
#  {'id': 88,
#   'name': 'Austria',
#   'year': 1908,
#   'gold': 0,
#   'silver': 0,
#   'bronze': 1},
#  {'id': 89,
#   'name': 'Austria',
#   'year': 1912,
#   'gold': 0,
#   'silver': 9,
#   'bronze': 5},
#  {'id': 90,
#   'name': 'Austria',
#   'year': 1924,
#   'gold': 3,
#   'silver': 4,
#   'bronze': 1},
#  {'id': 91,
#   'name': 'Austria',
#   'year': 1928,
#   'gold': 3,
#   'silver': 2,
#   'bronze': 2},
#  {'id': 92,
#   'name': 'Austria',
#   'year': 1932,
#   'gold': 2,
#   'silver': 2,
#   'bronze': 3},
#  {'id': 93,
#   'name': 'Austria',
#   'year': 1936,
#   'gold': 7,
#   'silver': 42,
#   'bronze': 9},
#  {'id': 94,
#   'name': 'Austria',
#   'year': 1948,
#   'gold': 3,
#   'silver': 5,
#   'bronze': 8},
#  {'id': 95,
#   'name': 'Austria',
#   'year': 1952,
#   'gold': 2,
#   'silver': 5,
#   'bronze': 4},
#  {'id': 96,
#   'name': 'Austria',
#   'year': 1956,
#   'gold': 3,
#   'silver': 3,
#   'bronze': 8},
#  {'id': 97,
#   'name': 'Austria',
#   'year': 1960,
#   'gold': 2,
#   'silver': 4,
#   'bronze': 3},
#  {'id': 98,
#   'name': 'Austria',
#   'year': 1964,
#   'gold': 3,
#   'silver': 3,
#   'bronze': 3},
#  {'id': 99,
#   'name': 'Austria',
#   'year': 1968,
#   'gold': 3,
#   'silver': 4,
#   'bronze': 7},
#  {'id': 100,
#   'name': 'Austria',
#   'year': 1972,
#   'gold': 1,
#   'silver': 3,
#   'bronze': 4},
#  {'id': 101,
#   'name': 'Austria',
#   'year': 1976,
#   'gold': 2,
#   'silver': 2,
#   'bronze': 2},
#  {'id': 102,
#   'name': 'Austria',
#   'year': 1980,
#   'gold': 4,
#   'silver': 5,
#   'bronze': 2},
#  {'id': 103,
#   'name': 'Austria',
#   'year': 1984,
#   'gold': 1,
#   'silver': 1,
#   'bronze': 2},
#  {'id': 104,
#   'name': 'Austria',
#   'year': 1988,
#   'gold': 4,
#   'silver': 5,
#   'bronze': 4},
#  {'id': 105,
#   'name': 'Austria',
#   'year': 1992,
#   'gold': 5,
#   'silver': 16,
#   'bronze': 10},
#  {'id': 106,
#   'name': 'Austria',
#   'year': 1994,
#   'gold': 2,
#   'silver': 3,
#   'bronze': 7},
#  {'id': 107,
#   'name': 'Austria',
#   'year': 1996,
#   'gold': 0,
#   'silver': 1,
#   'bronze': 2},
#  {'id': 108,
#   'name': 'Austria',
#   'year': 1998,
#   'gold': 3,
#   'silver': 5,
#   'bronze': 12},
#  {'id': 109,
#   'name': 'Austria',
#   'year': 2000,
#   'gold': 3,
#   'silver': 1,
#   'bronze': 0},
#  {'id': 110,
#   'name': 'Austria',
#   'year': 2002,
#   'gold': 3,
#   'silver': 4,
#   'bronze': 13},
#  {'id': 111,
#   'name': 'Austria',
#   'year': 2004,
#   'gold': 3,
#   'silver': 4,
#   'bronze': 1},
#  {'id': 112,
#   'name': 'Austria',
#   'year': 2006,
#   'gold': 14,
#   'silver': 7,
#   'bronze': 7},
#  {'id': 113,
#   'name': 'Austria',
#   'year': 2008,
#   'gold': 0,
#   'silver': 1,
#   'bronze': 2},
#  {'id': 114,
#   'name': 'Austria',
#   'year': 2010,
#   'gold': 9,
#   'silver': 9,
#   'bronze': 6},
#  {'id': 115,
#   'name': 'Austria',
#   'year': 2014,
#   'gold': 4,
#   'silver': 10,
#   'bronze': 11},
#  {'id': 116,
#   'name': 'Austria',
#   'year': 2016,
#   'gold': 0,
#   'silver': 0,
#   'bronze': 2},
#  {'id': 117,
#   'name': 'Austria-1',
#   'year': 1928,
#   'gold': 0,
#   'silver': 2,
#   'bronze': 0},
#  {'id': 118,
#   'name': 'Austria-1',
#   'year': 1936,
#   'gold': 0,
#   'silver': 2,
#   'bronze': 0},
#  {'id': 119,
#   'name': 'Austria-1',
#   'year': 1956,
#   'gold': 2,
#   'silver': 0,
#   'bronze': 0},
#  {'id': 120,
#   'name': 'Austria-1',
#   'year': 1964,
#   'gold': 2,
#   'silver': 4,
#   'bronze': 0},
#  {'id': 121,
#   'name': 'Austria-1',
#   'year': 1968,
#   'gold': 0,
#   'silver': 6,
#   'bronze': 0},
#  {'id': 122,
#   'name': 'Austria-1',
#   'year': 1976,
#   'gold': 0,
#   'silver': 0,
#   'bronze': 2},
#  {'id': 123,
#   'name': 'Austria-1',
#   'year': 1980,
#   'gold': 0,
#   'silver': 0,
#   'bronze': 2},
#  {'id': 124,
#   'name': 'Austria-1',
#   'year': 1992,
#   'gold': 4,
#   'silver': 0,
#   'bronze': 0},
#  {'id': 125,
#   'name': 'Austria-1',
#   'year': 2006,
#   'gold': 2,
#   'silver': 0,
#   'bronze': 0},
#  {'id': 126,
#   'name': 'Austria-1',
#   'year': 2010,
#   'gold': 2,
#   'silver': 0,
#   'bronze': 0},
#  {'id': 127,
#   'name': 'Austria-1',
#   'year': 2014,
#   'gold': 0,
#   'silver': 2,
#   'bronze': 0},
#  {'id': 128,
#   'name': 'Austria-2',
#   'year': 1928,
#   'gold': 0,
#   'silver': 0,
#   'bronze': 2},
#  {'id': 129,
#   'name': 'Austria-2',
#   'year': 1964,
#   'gold': 0,
#   'silver': 2,
#   'bronze': 0},
#  {'id': 130,
#   'name': 'Azerbaijan',
#   'year': 1996,
#   'gold': 0,
#   'silver': 1,
#   'bronze': 0},
#  {'id': 131,
#   'name': 'Azerbaijan',
#   'year': 2000,
#   'gold': 2,
#   'silver': 0,
#   'bronze': 1},
#  {'id': 132,
#   'name': 'Azerbaijan',
#   'year': 2004,
#   'gold': 1,
#   'silver': 0,
#   'bronze': 4},
#  {'id': 133,
#   'name': 'Azerbaijan',
#   'year': 2008,
#   'gold': 1,
#   'silver': 2,
#   'bronze': 4},
#  {'id': 134,
#   'name': 'Azerbaijan',
#   'year': 2012,
#   'gold': 2,
#   'silver': 2,
#   'bronze': 6},
#  {'id': 135,
#   'name': 'Azerbaijan',
#   'year': 2016,
#   'gold': 1,
#   'silver': 7,
#   'bronze': 10},
#  {'id': 136,
#   'name': 'BLO Polo Club, Rugby',
#   'year': 1900,
#   'gold': 0,
#   'silver': 4,
#   'bronze': 0},
#  {'id': 137,
#   'name': 'Baby-1',
#   'year': 1900,
#   'gold': 1,
#   'silver': 0,
#   'bronze': 1},
#  {'id': 138,
#   'name': 'Bagatelle Polo Club, Paris',
#   'year': 1900,
#   'gold': 0,
#   'silver': 0,
#   'bronze': 4},
#  {'id': 139,
#   'name': 'Bahamas',
#   'year': 1992,
#   'gold': 0,
#   'silver': 0,
#   'bronze': 1},
#  {'id': 140,
#   'name': 'Bahamas',
#   'year': 1996,
#   'gold': 0,
#   'silver': 5,
#   'bronze': 0},
#  {'id': 141,
#   'name': 'Bahamas',
#   'year': 2000,
#   'gold': 6,
#   'silver': 0,
#   'bronze': 5},
#  {'id': 142,
#   'name': 'Bahamas',
#   'year': 2004,
#   'gold': 1,
#   'silver': 0,
#   'bronze': 1},
#  {'id': 143,
#   'name': 'Bahamas',
#   'year': 2008,
#   'gold': 0,
#   'silver': 6,
#   'bronze': 1},
#  {'id': 144,
#   'name': 'Bahamas',
#   'year': 2012,
#   'gold': 4,
#   'silver': 0,
#   'bronze': 0},
#  {'id': 145,
#   'name': 'Bahamas',
#   'year': 2016,
#   'gold': 1,
#   'silver': 0,
#   'bronze': 5},
#  {'id': 146,
#   'name': 'Bahrain',
#   'year': 2012,
#   'gold': 0,
#   'silver': 0,
#   'bronze': 1},
#  {'id': 147,
#   'name': 'Bahrain',
#   'year': 2016,
#   'gold': 1,
#   'silver': 1,
#   'bronze': 0},
#  {'id': 148,
#   'name': 'Ballerina IV',
#   'year': 1960,
#   'gold': 0,
#   'silver': 0,
#   'bronze': 3},
#  {'id': 149,
#   'name': 'Barbados',
#   'year': 2000,
#   'gold': 0,
#   'silver': 0,
#   'bronze': 1},
#  {'id': 150,
#   'name': 'Barion/Bari-2',
#   'year': 1906,
#   'gold': 0,
#   'silver': 3,
#   'bronze': 0},
#  {'id': 151,
#   'name': 'Barrenjoey',
#   'year': 1964,
#   'gold': 3,
#   'silver': 0,
#   'bronze': 0},
#  {'id': 152,
#   'name': 'Beatrijs III-1',
#   'year': 1920,
#   'gold': 3,
#   'silver': 0,
#   'bronze': 0},
#  {'id': 153,
#   'name': 'Belarus',
#   'year': 1994,
#   'gold': 0,
#   'silver': 2,
#   'bronze': 0},
#  {'id': 154,
#   'name': 'Belarus',
#   'year': 1996,
#   'gold': 1,
#   'silver': 6,
#   'bronze': 16},
#  {'id': 155,
#   'name': 'Belarus',
#   'year': 1998,
#   'gold': 0,
#   'silver': 0,
#   'bronze': 2},
#  {'id': 156,
#   'name': 'Belarus',
#   'year': 2000,
#   'gold': 3,
#   'silver': 8,
#   'bronze': 11},
#  {'id': 157,
#   'name': 'Belarus',
#   'year': 2002,
#   'gold': 0,
#   'silver': 0,
#   'bronze': 1},
#  {'id': 158,
#   'name': 'Belarus',
#   'year': 2004,
#   'gold': 2,
#   'silver': 5,
#   'bronze': 8},
#  {'id': 159,
#   'name': 'Belarus',
#   'year': 2006,
#   'gold': 0,
#   'silver': 1,
#   'bronze': 0},
#  {'id': 160,
#   'name': 'Belarus',
#   'year': 2008,
#   'gold': 8,
#   'silver': 5,
#   'bronze': 16},
#  {'id': 161,
#   'name': 'Belarus',
#   'year': 2010,
#   'gold': 1,
#   'silver': 1,
#   'bronze': 1},
#  {'id': 162,
#   'name': 'Belarus',
#   'year': 2012,
#   'gold': 3,
#   'silver': 12,
#   'bronze': 8},
#  {'id': 163,
#   'name': 'Belarus',
#   'year': 2014,
#   'gold': 5,
#   'silver': 0,
#   'bronze': 1},
#  {'id': 164,
#   'name': 'Belarus',
#   'year': 2016,
#   'gold': 1,
#   'silver': 4,
#   'bronze': 7},
#  {'id': 165,
#   'name': 'Belgium',
#   'year': 1900,
#   'gold': 5,
#   'silver': 5,
#   'bronze': 4},
#  {'id': 166,
#   'name': 'Belgium',
#   'year': 1906,
#   'gold': 2,
#   'silver': 1,
#   'bronze': 6},
#  {'id': 167,
#   'name': 'Belgium',
#   'year': 1908,
#   'gold': 1,
#   'silver': 12,
#   'bronze': 8},
#  {'id': 168,
#   'name': 'Belgium',
#   'year': 1912,
#   'gold': 7,
#   'silver': 1,
#   'bronze': 11},
#  {'id': 169,
#   'name': 'Belgium',
#   'year': 1920,
#   'gold': 54,
#   'silver': 62,
#   'bronze': 61},
#  {'id': 170,
#   'name': 'Belgium',
#   'year': 1924,
#   'gold': 3,
#   'silver': 30,
#   'bronze': 6},
#  {'id': 171,
#   'name': 'Belgium',
#   'year': 1928,
#   'gold': 0,
#   'silver': 1,
#   'bronze': 5},
#  {'id': 172,
#   'name': 'Belgium',
#   'year': 1932,
#   'gold': 0,
#   'silver': 0,
#   'bronze': 1},
#  {'id': 173,
#   'name': 'Belgium',
#   'year': 1936,
#   'gold': 0,
#   'silver': 0,
#   'bronze': 14},
#  {'id': 174,
#   'name': 'Belgium',
#   'year': 1948,
#   'gold': 7,
#   'silver': 6,
#   'bronze': 8},
#  {'id': 175,
#   'name': 'Belgium',
#   'year': 1952,
#   'gold': 5,
#   'silver': 3,
#   'bronze': 0},
#  {'id': 176,
#   'name': 'Belgium',
#   'year': 1956,
#   'gold': 0,
#   'silver': 2,
#   'bronze': 0},
#  {'id': 177,
#   'name': 'Belgium',
#   'year': 1960,
#   'gold': 0,
#   'silver': 2,
#   'bronze': 2},
#  {'id': 178,
#   'name': 'Belgium',
#   'year': 1964,
#   'gold': 2,
#   'silver': 0,
#   'bronze': 1},
#  {'id': 179,
#   'name': 'Belgium',
#   'year': 1968,
#   'gold': 0,
#   'silver': 1,
#   'bronze': 2},
#  {'id': 180,
#   'name': 'Belgium',
#   'year': 1972,
#   'gold': 0,
#   'silver': 2,
#   'bronze': 0},
#  {'id': 181,
#   'name': 'Belgium',
#   'year': 1976,
#   'gold': 0,
#   'silver': 3,
#   'bronze': 6},
#  {'id': 182,
#   'name': 'Belgium',
#   'year': 1980,
#   'gold': 1,
#   'silver': 0,
#   'bronze': 0},
#  {'id': 183,
#   'name': 'Belgium',
#   'year': 1984,
#   'gold': 1,
#   'silver': 2,
#   'bronze': 2},
#  {'id': 184,
#   'name': 'Belgium',
#   'year': 1988,
#   'gold': 0,
#   'silver': 0,
#   'bronze': 2},
#  {'id': 185,
#   'name': 'Belgium',
#   'year': 1992,
#   'gold': 0,
#   'silver': 1,
#   'bronze': 2},
#  {'id': 186,
#   'name': 'Belgium',
#   'year': 1996,
#   'gold': 2,
#   'silver': 2,
#   'bronze': 2},
#  {'id': 187,
#   'name': 'Belgium',
#   'year': 1998,
#   'gold': 0,
#   'silver': 0,
#   'bronze': 1},
#  {'id': 188,
#   'name': 'Belgium',
#   'year': 2000,
#   'gold': 0,
#   'silver': 3,
#   'bronze': 4},
#  {'id': 189,
#   'name': 'Belgium',
#   'year': 2004,
#   'gold': 1,
#   'silver': 0,
#   'bronze': 2},
#  {'id': 190,
#   'name': 'Belgium',
#   'year': 2008,
#   'gold': 1,
#   'silver': 4,
#   'bronze': 0},
#  {'id': 191,
#   'name': 'Belgium',
#   'year': 2012,
#   'gold': 0,
#   'silver': 1,
#   'bronze': 2},
#  {'id': 192,
#   'name': 'Belgium',
#   'year': 2016,
#   'gold': 2,
#   'silver': 17,
#   'bronze': 2},
#  {'id': 193,
#   'name': 'Belgium-1',
#   'year': 1900,
#   'gold': 1,
#   'silver': 0,
#   'bronze': 0},
#  {'id': 194,
#   'name': 'Belgium-1',
#   'year': 1924,
#   'gold': 0,
#   'silver': 0,
#   'bronze': 5},
#  {'id': 195,
#   'name': 'Bem II',
#   'year': 1936,
#   'gold': 0,
#   'silver': 0,
#   'bronze': 2},
#  {'id': 196,
#   'name': 'Bera',
#   'year': 1924,
#   'gold': 5,
#   'silver': 0,
#   'bronze': 0},
#  {'id': 197,
#   'name': 'Berliner Ruderclub',
#   'year': 1908,
#   'gold': 0,
#   'silver': 0,
#   'bronze': 2},
#  {'id': 198,
#   'name': 'Berliner Ruderverein von 1876-2',
#   'year': 1912,
#   'gold': 0,
#   'silver': 0,
#   'bronze': 9},
#  {'id': 199,
#   'name': 'Bermuda',
#   'year': 1976,
#   'gold': 0,
#   'silver': 0,
#   'bronze': 1},
#  {'id': 200,
#   'name': 'Bingo',
#   'year': 1964,
#   'gold': 0,
#   'silver': 0,
#   'bronze': 3},
#  {'id': 201,
#   'name': 'Bissbi',
#   'year': 1932,
#   'gold': 4,
#   'silver': 0,
#   'bronze': 0},
#  {'id': 202,
#   'name': 'Bluebottle',
#   'year': 1956,
#   'gold': 0,
#   'silver': 0,
#   'bronze': 3},
#  {'id': 203,
#   'name': 'Bohemia',
#   'year': 1900,
#   'gold': 0,
#   'silver': 1,
#   'bronze': 1},
#  {'id': 204,
#   'name': 'Bohemia',
#   'year': 1906,
#   'gold': 0,
#   'silver': 0,
#   'bronze': 3},
#  {'id': 205,
#   'name': 'Bohemia',
#   'year': 1908,
#   'gold': 0,
#   'silver': 0,
#   'bronze': 6},
#  {'id': 206,
#   'name': 'Bohemia/Great Britain',
#   'year': 1900,
#   'gold': 0,
#   'silver': 0,
#   'bronze': 2},
#  {'id': 207,
#   'name': 'Bona Fide',
#   'year': 1900,
#   'gold': 3,
#   'silver': 0,
#   'bronze': 0},
#  {'id': 208,
#   'name': 'Bonaparte',
#   'year': 2008,
#   'gold': 1,
#   'silver': 0,
#   'bronze': 0},
#  {'id': 209,
#   'name': 'Bonzo',
#   'year': 1924,
#   'gold': 0,
#   'silver': 3,
#   'bronze': 0},
#  {'id': 210,
#   'name': 'Boreas-2',
#   'year': 1920,
#   'gold': 0,
#   'silver': 2,
#   'bronze': 0},
#  {'id': 211,
#   'name': 'Boston Archers',
#   'year': 1904,
#   'gold': 0,
#   'silver': 0,
#   'bronze': 4},
#  {'id': 212,
#   'name': 'Botswana',
#   'year': 2012,
#   'gold': 0,
#   'silver': 1,
#   'bronze': 0},
#  {'id': 213,
#   'name': 'Brazil',
#   'year': 1920,
#   'gold': 1,
#   'silver': 1,
#   'bronze': 5},
#  {'id': 214,
#   'name': 'Brazil',
#   'year': 1948,
#   'gold': 0,
#   'silver': 0,
#   'bronze': 10},
#  {'id': 215,
#   'name': 'Brazil',
#   'year': 1952,
#   'gold': 1,
#   'silver': 0,
#   'bronze': 2},
#  {'id': 216,
#   'name': 'Brazil',
#   'year': 1956,
#   'gold': 1,
#   'silver': 0,
#   'bronze': 0},
#  {'id': 217,
#   'name': 'Brazil',
#   'year': 1960,
#   'gold': 0,
#   'silver': 0,
#   'bronze': 13},
#  {'id': 218,
#   'name': 'Brazil',
#   'year': 1964,
#   'gold': 0,
#   'silver': 0,
#   'bronze': 12},
#  {'id': 219,
#   'name': 'Brazil',
#   'year': 1968,
#   'gold': 0,
#   'silver': 1,
#   'bronze': 3},
#  {'id': 220,
#   'name': 'Brazil',
#   'year': 1972,
#   'gold': 0,
#   'silver': 0,
#   'bronze': 2},
#  {'id': 221,
#   'name': 'Brazil',
#   'year': 1976,
#   'gold': 0,
#   'silver': 0,
#   'bronze': 3},
#  {'id': 222,
#   'name': 'Brazil',
#   'year': 1980,
#   'gold': 4,
#   'silver': 0,
#   'bronze': 5},
#  {'id': 223,
#   'name': 'Brazil',
#   'year': 1984,
#   'gold': 1,
#   'silver': 33,
#   'bronze': 2},
#  {'id': 224,
#   'name': 'Brazil',
#   'year': 1988,
#   'gold': 1,
#   'silver': 17,
#   'bronze': 5},
#  {'id': 225,
#   'name': 'Brazil',
#   'year': 1992,
#   'gold': 13,
#   'silver': 1,
#   'bronze': 0},
#  {'id': 226,
#   'name': 'Brazil',
#   'year': 1996,
#   'gold': 3,
#   'silver': 13,
#   'bronze': 43},
#  {'id': 227,
#   'name': 'Brazil',
#   'year': 2000,
#   'gold': 0,
#   'silver': 8,
#   'bronze': 34},
#  {'id': 228,
#   'name': 'Brazil',
#   'year': 2004,
#   'gold': 16,
#   'silver': 17,
#   'bronze': 3},
#  {'id': 229,
#   'name': 'Brazil',
#   'year': 2008,
#   'gold': 14,
#   'silver': 32,
#   'bronze': 28},
#  {'id': 230,
#   'name': 'Brazil',
#   'year': 2012,
#   'gold': 14,
#   'silver': 32,
#   'bronze': 9},
#  {'id': 231,
#   'name': 'Brazil',
#   'year': 2016,
#   'gold': 34,
#   'silver': 6,
#   'bronze': 6},
#  {'id': 232,
#   'name': 'Brazil-1',
#   'year': 1996,
#   'gold': 2,
#   'silver': 0,
#   'bronze': 0},
#  {'id': 233,
#   'name': 'Brazil-1',
#   'year': 2000,
#   'gold': 0,
#   'silver': 4,
#   'bronze': 0},
#  {'id': 234,
#   'name': 'Brazil-1',
#   'year': 2004,
#   'gold': 2,
#   'silver': 2,
#   'bronze': 0},
#  {'id': 235,
#   'name': 'Brazil-1',
#   'year': 2008,
#   'gold': 0,
#   'silver': 2,
#   'bronze': 0},
#  {'id': 236,
#   'name': 'Brazil-1',
#   'year': 2012,
#   'gold': 0,
#   'silver': 2,
#   'bronze': 2},
#  {'id': 237,
#   'name': 'Brazil-1',
#   'year': 2016,
#   'gold': 2,
#   'silver': 2,
#   'bronze': 0},
#  {'id': 238,
#   'name': 'Brazil-2',
#   'year': 1996,
#   'gold': 0,
#   'silver': 2,
#   'bronze': 0},
#  {'id': 239,
#   'name': 'Brazil-2',
#   'year': 2000,
#   'gold': 0,
#   'silver': 0,
#   'bronze': 2},
#  {'id': 240,
#   'name': 'Brazil-2',
#   'year': 2008,
#   'gold': 0,
#   'silver': 0,
#   'bronze': 2},
#  {'id': 241,
#   'name': 'Brussels Swimming and Water Polo Club',
#   'year': 1900,
#   'gold': 0,
#   'silver': 10,
#   'bronze': 0},
#  {'id': 242,
#   'name': 'Brynhild-2',
#   'year': 1900,
#   'gold': 0,
#   'silver': 1,
#   'bronze': 0},
#  {'id': 243,
#   'name': 'Bucintoro Venezia',
#   'year': 1906,
#   'gold': 8,
#   'silver': 0,
#   'bronze': 0},
#  {'id': 244,
#   'name': 'Bucintoro Venezia-1',
#   'year': 1906,
#   'gold': 3,
#   'silver': 0,
#   'bronze': 0},
#  {'id': 245,
#   'name': 'Bulgaria',
#   'year': 1952,
#   'gold': 0,
#   'silver': 0,
#   'bronze': 1},
#  {'id': 246,
#   'name': 'Bulgaria',
#   'year': 1956,
#   'gold': 1,
#   'silver': 3,
#   'bronze': 14},
#  {'id': 247,
#   'name': 'Bulgaria',
#   'year': 1960,
#   'gold': 1,
#   'silver': 3,
#   'bronze': 3},
#  {'id': 248,
#   'name': 'Bulgaria',
#   'year': 1964,
#   'gold': 3,
#   'silver': 5,
#   'bronze': 2},
#  {'id': 249,
#   'name': 'Bulgaria',
#   'year': 1968,
#   'gold': 2,
#   'silver': 21,
#   'bronze': 3},
#  {'id': 250,
#   'name': 'Bulgaria',
#   'year': 1972,
#   'gold': 6,
#   'silver': 10,
#   'bronze': 6},
#  {'id': 251,
#   'name': 'Bulgaria',
#   'year': 1976,
#   'gold': 8,
#   'silver': 13,
#   'bronze': 18},
#  {'id': 252,
#   'name': 'Bulgaria',
#   'year': 1980,
#   'gold': 8,
#   'silver': 44,
#   'bronze': 39},
#  {'id': 253,
#   'name': 'Bulgaria',
#   'year': 1988,
#   'gold': 10,
#   'silver': 14,
#   'bronze': 17},
#  {'id': 254,
#   'name': 'Bulgaria',
#   'year': 1992,
#   'gold': 3,
#   'silver': 7,
#   'bronze': 7},
#  {'id': 255,
#   'name': 'Bulgaria',
#   'year': 1996,
#   'gold': 3,
#   'silver': 12,
#   'bronze': 6},
#  {'id': 256,
#   'name': 'Bulgaria',
#   'year': 1998,
#   'gold': 1,
#   'silver': 0,
#   'bronze': 0},
#  {'id': 257,
#   'name': 'Bulgaria',
#   'year': 2000,
#   'gold': 5,
#   'silver': 6,
#   'bronze': 2},
#  {'id': 258,
#   'name': 'Bulgaria',
#   'year': 2002,
#   'gold': 0,
#   'silver': 1,
#   'bronze': 2},
#  {'id': 259,
#   'name': 'Bulgaria',
#   'year': 2004,
#   'gold': 2,
#   'silver': 1,
#   'bronze': 14},
#  {'id': 260,
#   'name': 'Bulgaria',
#   'year': 2006,
#   'gold': 0,
#   'silver': 1,
#   'bronze': 0},
#  {'id': 261,
#   'name': 'Bulgaria',
#   'year': 2008,
#   'gold': 1,
#   'silver': 1,
#   'bronze': 3},
#  {'id': 262,
#   'name': 'Bulgaria',
#   'year': 2012,
#   'gold': 0,
#   'silver': 1,
#   'bronze': 1},
#  {'id': 263,
#   'name': 'Bulgaria',
#   'year': 2016,
#   'gold': 0,
#   'silver': 1,
#   'bronze': 6},
#  {'id': 264,
#   'name': 'Buraddoo',
#   'year': 1956,
#   'gold': 0,
#   'silver': 0,
#   'bronze': 3},
#  {'id': 265,
#   'name': 'Burundi',
#   'year': 1996,
#   'gold': 1,
#   'silver': 0,
#   'bronze': 0},
#  {'id': 266,
#   'name': 'Burundi',
#   'year': 2016,
#   'gold': 0,
#   'silver': 1,
#   'bronze': 0},
#  {'id': 267,
#   'name': 'Cambridge University Boat Club-2',
#   'year': 1908,
#   'gold': 0,
#   'silver': 0,
#   'bronze': 9},
#  {'id': 268,
#   'name': 'Cameroon',
#   'year': 1968,
#   'gold': 0,
#   'silver': 1,
#   'bronze': 0},
#  {'id': 269,
#   'name': 'Cameroon',
#   'year': 1984,
#   'gold': 0,
#   'silver': 0,
#   'bronze': 1},
#  {'id': 270,
#   'name': 'Cameroon',
#   'year': 2000,
#   'gold': 18,
#   'silver': 0,
#   'bronze': 0},
#  {'id': 271,
#   'name': 'Cameroon',
#   'year': 2004,
#   'gold': 1,
#   'silver': 0,
#   'bronze': 0},
#  {'id': 272,
#   'name': 'Cameroon',
#   'year': 2008,
#   'gold': 1,
#   'silver': 0,
#   'bronze': 0},
#  {'id': 273,
#   'name': 'Camille',
#   'year': 1908,
#   'gold': 1,
#   'silver': 0,
#   'bronze': 0},
#  {'id': 274,
#   'name': 'Canada',
#   'year': 1900,
#   'gold': 1,
#   'silver': 0,
#   'bronze': 1},
#  {'id': 275,
#   'name': 'Canada',
#   'year': 1904,
#   'gold': 2,
#   'silver': 0,
#   'bronze': 0},
#  {'id': 276,
#   'name': 'Canada',
#   'year': 1906,
#   'gold': 1,
#   'silver': 1,
#   'bronze': 0},
#  {'id': 277,
#   'name': 'Canada',
#   'year': 1908,
#   'gold': 14,
#   'silver': 8,
#   'bronze': 15},
#  {'id': 278,
#   'name': 'Canada',
#   'year': 1912,
#   'gold': 3,
#   'silver': 2,
#   'bronze': 3},
#  {'id': 279,
#   'name': 'Canada',
#   'year': 1920,
#   'gold': 10,
#   'silver': 3,
#   'bronze': 3},
#  {'id': 280,
#   'name': 'Canada',
#   'year': 1924,
#   'gold': 9,
#   'silver': 19,
#   'bronze': 1},
#  {'id': 281,
#   'name': 'Canada',
#   'year': 1928,
#   'gold': 19,
#   'silver': 5,
#   'bronze': 21},
#  {'id': 282,
#   'name': 'Canada',
#   'year': 1932,
#   'gold': 16,
#   'silver': 8,
#   'bronze': 25},
#  {'id': 283,
#   'name': 'Canada',
#   'year': 1936,
#   'gold': 1,
#   'silver': 25,
#   'bronze': 9},
#  {'id': 284,
#   'name': 'Canada',
#   'year': 1948,
#   'gold': 13,
#   'silver': 2,
#   'bronze': 7},
#  {'id': 285,
#   'name': 'Canada',
#   'year': 1952,
#   'gold': 17,
#   'silver': 3,
#   'bronze': 1},
#  {'id': 286,
#   'name': 'Canada',
#   'year': 1956,
#   'gold': 5,
#   'silver': 9,
#   'bronze': 23},
#  {'id': 287,
#   'name': 'Canada',
#   'year': 1960,
#   'gold': 1,
#   'silver': 26,
#   'bronze': 1},
#  {'id': 288,
#   'name': 'Canada',
#   'year': 1964,
#   'gold': 2,
#   'silver': 2,
#   'bronze': 2},
#  {'id': 289,
#   'name': 'Canada',
#   'year': 1968,
#   'gold': 4,
#   'silver': 4,
#   'bronze': 22},
#  {'id': 290,
#   'name': 'Canada',
#   'year': 1972,
#   'gold': 0,
#   'silver': 3,
#   'bronze': 9},
#  {'id': 291,
#   'name': 'Canada',
#   'year': 1976,
#   'gold': 1,
#   'silver': 10,
#   'bronze': 15},
#  {'id': 292,
#   'name': 'Canada',
#   'year': 1980,
#   'gold': 0,
#   'silver': 1,
#   'bronze': 1},
#  {'id': 293,
#   'name': 'Canada',
#   'year': 1984,
#   'gold': 21,
#   'silver': 37,
#   'bronze': 33},
#  {'id': 294,
#   'name': 'Canada',
#   'year': 1988,
#   'gold': 4,
#   'silver': 7,
#   'bronze': 16},
#  {'id': 295,
#   'name': 'Canada',
#   'year': 1992,
#   'gold': 32,
#   'silver': 33,
#   'bronze': 13},
#  {'id': 296,
#   'name': 'Canada',
#   'year': 1994,
#   'gold': 3,
#   'silver': 29,
#   'bronze': 3},
#  {'id': 297,
#   'name': 'Canada',
#   'year': 1996,
#   'gold': 8,
#   'silver': 30,
#   'bronze': 10},
#  {'id': 298,
#   'name': 'Canada',
#   'year': 1998,
#   'gold': 12,
#   'silver': 28,
#   'bronze': 7},
#  {'id': 299,
#   'name': 'Canada',
#   'year': 2000,
#   'gold': 4,
#   'silver': 4,
#   'bronze': 23},
#  {'id': 300,
#   'name': 'Canada',
#   'year': 2002,
#   'gold': 50,
#   'silver': 7,
#   'bronze': 15},
#  {'id': 301,
#   'name': 'Canada',
#   'year': 2004,
#   'gold': 3,
#   'silver': 10,
#   'bronze': 4},
#  {'id': 302,
#   'name': 'Canada',
#   'year': 2006,
#   'gold': 30,
#   'silver': 26,
#   'bronze': 11},
#  {'id': 303,
#   'name': 'Canada',
#   'year': 2008,
#   'gold': 11,
#   'silver': 13,
#   'bronze': 11},
#  {'id': 304,
#   'name': 'Canada',
#   'year': 2010,
#   'gold': 63,
#   'silver': 13,
#   'bronze': 4},
#  {'id': 305,
#   'name': 'Canada',
#   'year': 2012,
#   'gold': 1,
#   'silver': 21,
#   'bronze': 33},
#  {'id': 306,
#   'name': 'Canada',
#   'year': 2014,
#   'gold': 57,
#   'silver': 20,
#   'bronze': 5},
#  {'id': 307,
#   'name': 'Canada',
#   'year': 2016,
#   'gold': 4,
#   'silver': 4,
#   'bronze': 61},
#  {'id': 308,
#   'name': 'Canada-1',
#   'year': 1956,
#   'gold': 0,
#   'silver': 2,
#   'bronze': 0},
#  {'id': 309,
#   'name': 'Canada-1',
#   'year': 1960,
#   'gold': 2,
#   'silver': 0,
#   'bronze': 0},
#  {'id': 310,
#   'name': 'Canada-1',
#   'year': 1964,
#   'gold': 4,
#   'silver': 2,
#   'bronze': 0},
#  {'id': 311,
#   'name': 'Canada-1',
#   'year': 1988,
#   'gold': 0,
#   'silver': 0,
#   'bronze': 2},
#  {'id': 312,
#   'name': 'Canada-1',
#   'year': 1992,
#   'gold': 0,
#   'silver': 0,
#   'bronze': 2},
#  {'id': 313,
#   'name': 'Canada-1',
#   'year': 1994,
#   'gold': 0,
#   'silver': 0,
#   'bronze': 2},
#  {'id': 314,
#   'name': 'Canada-1',
#   'year': 1996,
#   'gold': 0,
#   'silver': 0,
#   'bronze': 2},
#  {'id': 315,
#   'name': 'Canada-1',
#   'year': 1998,
#   'gold': 2,
#   'silver': 0,
#   'bronze': 0},
#  {'id': 316,
#   'name': 'Canada-1',
#   'year': 2002,
#   'gold': 2,
#   'silver': 0,
#   'bronze': 0},
#  {'id': 317,
#   'name': 'Canada-1',
#   'year': 2006,
#   'gold': 0,
#   'silver': 2,
#   'bronze': 0},
#  {'id': 318,
#   'name': 'Canada-1',
#   'year': 2010,
#   'gold': 4,
#   'silver': 0,
#   'bronze': 4},
#  {'id': 319,
#   'name': 'Canada-1',
#   'year': 2014,
#   'gold': 2,
#   'silver': 2,
#   'bronze': 0},
#  {'id': 320,
#   'name': 'Canada-2',
#   'year': 2010,
#   'gold': 0,
#   'silver': 2,
#   'bronze': 0},
#  {'id': 321,
#   'name': 'Caprice',
#   'year': 1932,
#   'gold': 0,
#   'silver': 0,
#   'bronze': 4},
#  {'id': 322,
#   'name': 'Carabinier-15',
#   'year': 1900,
#   'gold': 1,
#   'silver': 0,
#   'bronze': 0},
#  {'id': 323,
#   'name': 'Central Turnverein, Chicago',
#   'year': 1904,
#   'gold': 0,
#   'silver': 0,
#   'bronze': 6},
#  {'id': 324,
#   'name': 'Century Boat Club-1',
#   'year': 1904,
#   'gold': 4,
#   'silver': 0,
#   'bronze': 0},
#  {'id': 325,
#   'name': "Cercle de l'Aviron Roubaix-4",
#   'year': 1900,
#   'gold': 5,
#   'silver': 0,
#   'bronze': 0},
#  {'id': 326,
#   'name': 'Chicago Athletic Association',
#   'year': 1904,
#   'gold': 0,
#   'silver': 5,
#   'bronze': 0},
#  {'id': 327,
#   'name': 'Chicago Athletic Association-2',
#   'year': 1904,
#   'gold': 0,
#   'silver': 11,
#   'bronze': 0},
#  {'id': 328,
#   'name': 'Chile',
#   'year': 1928,
#   'gold': 0,
#   'silver': 1,
#   'bronze': 0},
#  {'id': 329,
#   'name': 'Chile',
#   'year': 1952,
#   'gold': 0,
#   'silver': 4,
#   'bronze': 0},
#  {'id': 330,
#   'name': 'Chile',
#   'year': 1956,
#   'gold': 0,
#   'silver': 2,
#   'bronze': 2},
#  {'id': 331,
#   'name': 'Chile',
#   'year': 1988,
#   'gold': 0,
#   'silver': 1,
#   'bronze': 0},
#  {'id': 332,
#   'name': 'Chile',
#   'year': 2000,
#   'gold': 0,
#   'silver': 0,
#   'bronze': 17},
#  {'id': 333,
#   'name': 'Chile',
#   'year': 2004,
#   'gold': 3,
#   'silver': 0,
#   'bronze': 1},
#  {'id': 334,
#   'name': 'Chile',
#   'year': 2008,
#   'gold': 0,
#   'silver': 1,
#   'bronze': 0},
#  {'id': 335,
#   'name': 'China',
#   'year': 1984,
#   'gold': 24,
#   'silver': 13,
#   'bronze': 37},
#  {'id': 336,
#   'name': 'China',
#   'year': 1988,
#   'gold': 4,
#   'silver': 16,
#   'bronze': 30},
#  {'id': 337,
#   'name': 'China',
#   'year': 1992,
#   'gold': 14,
#   'silver': 44,
#   'bronze': 15},
#  {'id': 338,
#   'name': 'China',
#   'year': 1994,
#   'gold': 0,
#   'silver': 1,
#   'bronze': 2},
#  {'id': 339,
#   'name': 'China',
#   'year': 1996,
#   'gold': 13,
#   'silver': 66,
#   'bronze': 15},
#  {'id': 340,
#   'name': 'China',
#   'year': 1998,
#   'gold': 0,
#   'silver': 9,
#   'bronze': 5},
#  {'id': 341,
#   'name': 'China',
#   'year': 2000,
#   'gold': 31,
#   'silver': 19,
#   'bronze': 15},
#  {'id': 342,
#   'name': 'China',
#   'year': 2002,
#   'gold': 2,
#   'silver': 5,
#   'bronze': 7},
#  {'id': 343,
#   'name': 'China',
#   'year': 2004,
#   'gold': 42,
#   'silver': 27,
#   'bronze': 13},
#  {'id': 344,
#   'name': 'China',
#   'year': 2006,
#   'gold': 2,
#   'silver': 3,
#   'bronze': 4},
#  {'id': 345,
#   'name': 'China',
#   'year': 2008,
#   'gold': 72,
#   'silver': 49,
#   'bronze': 49},
#  {'id': 346,
#   'name': 'China',
#   'year': 2010,
#   'gold': 7,
#   'silver': 1,
#   'bronze': 7},
#  {'id': 347,
#   'name': 'China',
#   'year': 2012,
#   'gold': 50,
#   'silver': 38,
#   'bronze': 29},
#  {'id': 348,
#   'name': 'China',
#   'year': 2014,
#   'gold': 3,
#   'silver': 4,
#   'bronze': 5},
#  {'id': 349,
#   'name': 'China',
#   'year': 2016,
#   'gold': 44,
#   'silver': 30,
#   'bronze': 35},
#  {'id': 350,
#   'name': 'China-1',
#   'year': 1988,
#   'gold': 2,
#   'silver': 0,
#   'bronze': 0},
#  {'id': 351,
#   'name': 'China-1',
#   'year': 1992,
#   'gold': 2,
#   'silver': 4,
#   'bronze': 0},
#  {'id': 352,
#   'name': 'China-1',
#   'year': 1996,
#   'gold': 2,
#   'silver': 2,
#   'bronze': 0},
#  {'id': 353,
#   'name': 'China-1',
#   'year': 2000,
#   'gold': 2,
#   'silver': 2,
#   'bronze': 2},
#  {'id': 354,
#   'name': 'China-1',
#   'year': 2002,
#   'gold': 0,
#   'silver': 0,
#   'bronze': 2},
#  {'id': 355,
#   'name': 'China-1',
#   'year': 2004,
#   'gold': 8,
#   'silver': 0,
#   'bronze': 0},
#  {'id': 356,
#   'name': 'China-1',
#   'year': 2006,
#   'gold': 0,
#   'silver': 2,
#   'bronze': 0},
#  {'id': 357,
#   'name': 'China-1',
#   'year': 2008,
#   'gold': 2,
#   'silver': 4,
#   'bronze': 4},
#  {'id': 358,
#   'name': 'China-1',
#   'year': 2010,
#   'gold': 2,
#   'silver': 0,
#   'bronze': 0},
#  {'id': 359,
#   'name': 'China-1',
#   'year': 2012,
#   'gold': 6,
#   'silver': 0,
#   'bronze': 0},
#  {'id': 360,
#   'name': 'China-1',
#   'year': 2016,
#   'gold': 2,
#   'silver': 0,
#   'bronze': 2},
#  {'id': 361,
#   'name': 'China-2',
#   'year': 1992,
#   'gold': 2,
#   'silver': 0,
#   'bronze': 4},
#  {'id': 362,
#   'name': 'China-2',
#   'year': 1996,
#   'gold': 4,
#   'silver': 2,
#   'bronze': 2},
#  {'id': 363,
#   'name': 'China-2',
#   'year': 2000,
#   'gold': 6,
#   'silver': 2,
#   'bronze': 0},
#  {'id': 364,
#   'name': 'China-2',
#   'year': 2004,
#   'gold': 2,
#   'silver': 0,
#   'bronze': 2},
#  {'id': 365,
#   'name': 'China-2',
#   'year': 2008,
#   'gold': 0,
#   'silver': 0,
#   'bronze': 4},
#  {'id': 366,
#   'name': 'China-2',
#   'year': 2010,
#   'gold': 0,
#   'silver': 2,
#   'bronze': 0},
#  {'id': 367,
#   'name': 'China-2',
#   'year': 2012,
#   'gold': 0,
#   'silver': 2,
#   'bronze': 0},
#  {'id': 368,
#   'name': 'China-3',
#   'year': 2006,
#   'gold': 0,
#   'silver': 0,
#   'bronze': 2},
#  {'id': 369,
#   'name': 'Chinese Taipei',
#   'year': 1960,
#   'gold': 0,
#   'silver': 1,
#   'bronze': 0},
#  {'id': 370,
#   'name': 'Chinese Taipei',
#   'year': 1968,
#   'gold': 0,
#   'silver': 0,
#   'bronze': 1},
#  {'id': 371,
#   'name': 'Chinese Taipei',
#   'year': 1984,
#   'gold': 0,
#   'silver': 0,
#   'bronze': 1},
#  {'id': 372,
#   'name': 'Chinese Taipei',
#   'year': 1992,
#   'gold': 0,
#   'silver': 20,
#   'bronze': 0},
#  {'id': 373,
#   'name': 'Chinese Taipei',
#   'year': 1996,
#   'gold': 0,
#   'silver': 1,
#   'bronze': 0},
#  {'id': 374,
#   'name': 'Chinese Taipei',
#   'year': 2000,
#   'gold': 0,
#   'silver': 1,
#   'bronze': 4},
#  {'id': 375,
#   'name': 'Chinese Taipei',
#   'year': 2004,
#   'gold': 2,
#   'silver': 4,
#   'bronze': 3},
#  {'id': 376,
#   'name': 'Chinese Taipei',
#   'year': 2008,
#   'gold': 0,
#   'silver': 0,
#   'bronze': 4},
#  {'id': 377,
#   'name': 'Chinese Taipei',
#   'year': 2012,
#   'gold': 0,
#   'silver': 1,
#   'bronze': 1},
#  {'id': 378,
#   'name': 'Chinese Taipei',
#   'year': 2016,
#   'gold': 1,
#   'silver': 0,
#   'bronze': 4},
#  {'id': 379,
#   'name': "Christian Brothers' College-1",
#   'year': 1904,
#   'gold': 0,
#   'silver': 11,
#   'bronze': 0},
#  {'id': 380,
#   'name': 'Chuckles',
#   'year': 1956,
#   'gold': 0,
#   'silver': 0,
#   'bronze': 2},
#  {'id': 381,
#   'name': 'Cicely-1',
#   'year': 1900,
#   'gold': 1,
#   'silver': 0,
#   'bronze': 0},
#  {'id': 382,
#   'name': 'Cincinnati Archers',
#   'year': 1904,
#   'gold': 4,
#   'silver': 4,
#   'bronze': 0},
#  {'id': 383,
#   'name': 'Clearwater',
#   'year': 2008,
#   'gold': 0,
#   'silver': 0,
#   'bronze': 1},
#  {'id': 384,
#   'name': 'Club Nautique de Lyon-2',
#   'year': 1900,
#   'gold': 0,
#   'silver': 4,
#   'bronze': 0},
#  {'id': 385,
#   'name': 'Cobweb-1',
#   'year': 1908,
#   'gold': 5,
#   'silver': 0,
#   'bronze': 0},
#  {'id': 386,
#   'name': 'Colombia',
#   'year': 1972,
#   'gold': 0,
#   'silver': 1,
#   'bronze': 2},
#  {'id': 387,
#   'name': 'Colombia',
#   'year': 1984,
#   'gold': 0,
#   'silver': 1,
#   'bronze': 0},
#  {'id': 388,
#   'name': 'Colombia',
#   'year': 1988,
#   'gold': 0,
#   'silver': 0,
#   'bronze': 1},
#  {'id': 389,
#   'name': 'Colombia',
#   'year': 1992,
#   'gold': 0,
#   'silver': 0,
#   'bronze': 1},
#  {'id': 390,
#   'name': 'Colombia',
#   'year': 2000,
#   'gold': 1,
#   'silver': 0,
#   'bronze': 0},
#  {'id': 391,
#   'name': 'Colombia',
#   'year': 2004,
#   'gold': 0,
#   'silver': 0,
#   'bronze': 2},
#  {'id': 392,
#   'name': 'Colombia',
#   'year': 2008,
#   'gold': 0,
#   'silver': 1,
#   'bronze': 1},
#  {'id': 393,
#   'name': 'Colombia',
#   'year': 2012,
#   'gold': 1,
#   'silver': 3,
#   'bronze': 4},
#  {'id': 394,
#   'name': 'Colombia',
#   'year': 2016,
#   'gold': 3,
#   'silver': 2,
#   'bronze': 3},
#  {'id': 395,
#   'name': 'Comanche',
#   'year': 1952,
#   'gold': 0,
#   'silver': 2,
#   'bronze': 0},
#  {'id': 396,
#   'name': 'Complex II',
#   'year': 1952,
#   'gold': 4,
#   'silver': 0,
#   'bronze': 0},
#  {'id': 397,
#   'name': 'Cornwall',
#   'year': 1908,
#   'gold': 0,
#   'silver': 15,
#   'bronze': 0},
#  {'id': 398,
#   'name': 'Costa Rica',
#   'year': 1988,
#   'gold': 0,
#   'silver': 1,
#   'bronze': 0},
#  {'id': 399,
#   'name': 'Costa Rica',
#   'year': 1996,
#   'gold': 1,
#   'silver': 0,
#   'bronze': 0},
#  {'id': 400,
#   'name': 'Costa Rica',
#   'year': 2000,
#   'gold': 0,
#   'silver': 0,
#   'bronze': 2},
#  {'id': 401,
#   'name': "Cote d'Ivoire",
#   'year': 1984,
#   'gold': 0,
#   'silver': 1,
#   'bronze': 0},
#  {'id': 402,
#   'name': "Cote d'Ivoire",
#   'year': 2016,
#   'gold': 1,
#   'silver': 0,
#   'bronze': 1},
#  {'id': 403,
#   'name': 'Crabe II-1',
#   'year': 1900,
#   'gold': 0,
#   'silver': 5,
#   'bronze': 0},
#  {'id': 404,
#   'name': 'Crabe II-4',
#   'year': 1900,
#   'gold': 0,
#   'silver': 0,
#   'bronze': 5},
#  {'id': 405,
#   'name': 'Croatia',
#   'year': 1992,
#   'gold': 0,
#   'silver': 12,
#   'bronze': 3},
#  {'id': 406,
#   'name': 'Croatia',
#   'year': 1996,
#   'gold': 16,
#   'silver': 12,
#   'bronze': 0},
#  {'id': 407,
#   'name': 'Croatia',
#   'year': 2000,
#   'gold': 1,
#   'silver': 0,
#   'bronze': 9},
#  {'id': 408,
#   'name': 'Croatia',
#   'year': 2002,
#   'gold': 3,
#   'silver': 1,
#   'bronze': 0},
#  {'id': 409,
#   'name': 'Croatia',
#   'year': 2004,
#   'gold': 15,
#   'silver': 3,
#   'bronze': 3},
#  {'id': 410,
#   'name': 'Croatia',
#   'year': 2006,
#   'gold': 1,
#   'silver': 2,
#   'bronze': 0},
#  {'id': 411,
#   'name': 'Croatia',
#   'year': 2008,
#   'gold': 0,
#   'silver': 2,
#   'bronze': 3},
#  {'id': 412,
#   'name': 'Croatia',
#   'year': 2010,
#   'gold': 0,
#   'silver': 2,
#   'bronze': 1},
#  {'id': 413,
#   'name': 'Croatia',
#   'year': 2012,
#   'gold': 15,
#   'silver': 4,
#   'bronze': 16},
#  {'id': 414,
#   'name': 'Croatia',
#   'year': 2014,
#   'gold': 0,
#   'silver': 1,
#   'bronze': 0},
#  {'id': 415,
#   'name': 'Croatia',
#   'year': 2016,
#   'gold': 7,
#   'silver': 15,
#   'bronze': 2},
#  {'id': 416,
#   'name': 'Cuba',
#   'year': 1900,
#   'gold': 1,
#   'silver': 1,
#   'bronze': 0},
#  {'id': 417,
#   'name': 'Cuba',
#   'year': 1904,
#   'gold': 5,
#   'silver': 0,
#   'bronze': 0},
#  {'id': 418,
#   'name': 'Cuba',
#   'year': 1964,
#   'gold': 0,
#   'silver': 1,
#   'bronze': 0},
#  {'id': 419,
#   'name': 'Cuba',
#   'year': 1968,
#   'gold': 0,
#   'silver': 10,
#   'bronze': 0},
#  {'id': 420,
#   'name': 'Cuba',
#   'year': 1972,
#   'gold': 3,
#   'silver': 1,
#   'bronze': 18},
#  {'id': 421,
#   'name': 'Cuba',
#   'year': 1976,
#   'gold': 6,
#   'silver': 4,
#   'bronze': 14},
#  {'id': 422,
#   'name': 'Cuba',
#   'year': 1980,
#   'gold': 8,
#   'silver': 7,
#   'bronze': 5},
#  {'id': 423,
#   'name': 'Cuba',
#   'year': 1992,
#   'gold': 42,
#   'silver': 13,
#   'bronze': 14},
#  {'id': 424,
#   'name': 'Cuba',
#   'year': 1996,
#   'gold': 37,
#   'silver': 8,
#   'bronze': 10},
#  {'id': 425,
#   'name': 'Cuba',
#   'year': 2000,
#   'gold': 18,
#   'silver': 35,
#   'bronze': 12},
#  {'id': 426,
#   'name': 'Cuba',
#   'year': 2004,
#   'gold': 32,
#   'silver': 8,
#   'bronze': 22},
#  {'id': 427,
#   'name': 'Cuba',
#   'year': 2008,
#   'gold': 2,
#   'silver': 34,
#   'bronze': 11},
#  {'id': 428,
#   'name': 'Cuba',
#   'year': 2012,
#   'gold': 5,
#   'silver': 3,
#   'bronze': 6},
#  {'id': 429,
#   'name': 'Cuba',
#   'year': 2016,
#   'gold': 5,
#   'silver': 2,
#   'bronze': 4},
#  {'id': 430,
#   'name': 'Cyprus',
#   'year': 2012,
#   'gold': 0,
#   'silver': 1,
#   'bronze': 0},
#  {'id': 431,
#   'name': 'Czech Republic',
#   'year': 1996,
#   'gold': 4,
#   'silver': 3,
#   'bronze': 4},
#  {'id': 432,
#   'name': 'Czech Republic',
#   'year': 1998,
#   'gold': 21,
#   'silver': 1,
#   'bronze': 1},
#  {'id': 433,
#   'name': 'Czech Republic',
#   'year': 2000,
#   'gold': 2,
#   'silver': 3,
#   'bronze': 2},
#  {'id': 434,
#   'name': 'Czech Republic',
#   'year': 2002,
#   'gold': 1,
#   'silver': 2,
#   'bronze': 0},
#  {'id': 435,
#   'name': 'Czech Republic',
#   'year': 2004,
#   'gold': 1,
#   'silver': 6,
#   'bronze': 4},
#  {'id': 436,
#   'name': 'Czech Republic',
#   'year': 2006,
#   'gold': 1,
#   'silver': 2,
#   'bronze': 24},
#  {'id': 437,
#   'name': 'Czech Republic',
#   'year': 2008,
#   'gold': 3,
#   'silver': 4,
#   'bronze': 0},
#  {'id': 438,
#   'name': 'Czech Republic',
#   'year': 2010,
#   'gold': 2,
#   'silver': 0,
#   'bronze': 7},
#  {'id': 439,
#   'name': 'Czech Republic',
#   'year': 2012,
#   'gold': 4,
#   'silver': 2,
#   'bronze': 6},
#  {'id': 440,
#   'name': 'Czech Republic',
#   'year': 2014,
#   'gold': 2,
#   'silver': 7,
#   'bronze': 2},
#  {'id': 441,
#   'name': 'Czech Republic',
#   'year': 2016,
#   'gold': 1,
#   'silver': 2,
#   'bronze': 10},
#  {'id': 442,
#   'name': 'Czech Republic-1',
#   'year': 1996,
#   'gold': 0,
#   'silver': 2,
#   'bronze': 0},
#  {'id': 443,
#   'name': 'Czech Republic-1',
#   'year': 2000,
#   'gold': 0,
#   'silver': 0,
#   'bronze': 2},
#  {'id': 444,
#   'name': 'Czech Republic-1',
#   'year': 2004,
#   'gold': 0,
#   'silver': 0,
#   'bronze': 2},
#  {'id': 445,
#   'name': 'Czech Republic-1',
#   'year': 2012,
#   'gold': 0,
#   'silver': 2,
#   'bronze': 0},
#  {'id': 446,
#   'name': 'Czech Republic-1',
#   'year': 2016,
#   'gold': 0,
#   'silver': 0,
#   'bronze': 2},
#  {'id': 447,
#   'name': 'Czechoslovakia',
#   'year': 1920,
#   'gold': 0,
#   'silver': 0,
#   'bronze': 10},
#  {'id': 448,
#   'name': 'Czechoslovakia',
#   'year': 1924,
#   'gold': 1,
#   'silver': 4,
#   'bronze': 5},
#  {'id': 449,
#   'name': 'Czechoslovakia',
#   'year': 1928,
#   'gold': 2,
#   'silver': 12,
#   'bronze': 3},
#  {'id': 450,
#   'name': 'Czechoslovakia',
#   'year': 1932,
#   'gold': 1,
#   'silver': 3,
#   'bronze': 2},
#  {'id': 451,
#   'name': 'Czechoslovakia',
#   'year': 1936,
#   'gold': 5,
#   'silver': 12,
#   'bronze': 1},
#  {'id': 452,
#   'name': 'Czechoslovakia',
#   'year': 1948,
#   'gold': 14,
#   'silver': 20,
#   'bronze': 3},
#  {'id': 453,
#   'name': 'Czechoslovakia',
#   'year': 1952,
#   'gold': 11,
#   'silver': 4,
#   'bronze': 10},
#  {'id': 454,
#   'name': 'Czechoslovakia',
#   'year': 1956,
#   'gold': 1,
#   'silver': 5,
#   'bronze': 1},
#  {'id': 455,
#   'name': 'Czechoslovakia',
#   'year': 1960,
#   'gold': 4,
#   'silver': 8,
#   'bronze': 11},
#  {'id': 456,
#   'name': 'Czechoslovakia',
#   'year': 1964,
#   'gold': 5,
#   'silver': 37,
#   'bronze': 29},
#  {'id': 457,
#   'name': 'Czechoslovakia',
#   'year': 1968,
#   'gold': 8,
#   'silver': 26,
#   'bronze': 16},
#  {'id': 458,
#   'name': 'Czechoslovakia',
#   'year': 1972,
#   'gold': 3,
#   'silver': 21,
#   'bronze': 25},
#  {'id': 459,
#   'name': 'Czechoslovakia',
#   'year': 1976,
#   'gold': 2,
#   'silver': 23,
#   'bronze': 9},
#  {'id': 460,
#   'name': 'Czechoslovakia',
#   'year': 1980,
#   'gold': 17,
#   'silver': 18,
#   'bronze': 17},
#  {'id': 461,
#   'name': 'Czechoslovakia',
#   'year': 1984,
#   'gold': 0,
#   'silver': 24,
#   'bronze': 4},
#  {'id': 462,
#   'name': 'Czechoslovakia',
#   'year': 1988,
#   'gold': 3,
#   'silver': 5,
#   'bronze': 8},
#  {'id': 463,
#   'name': 'Czechoslovakia',
#   'year': 1992,
#   'gold': 4,
#   'silver': 1,
#   'bronze': 28},
#  {'id': 464,
#   'name': 'Czechoslovakia-1',
#   'year': 1992,
#   'gold': 0,
#   'silver': 2,
#   'bronze': 0},
#  {'id': 465,
#   'name': 'Denmark',
#   'year': 1896,
#   'gold': 1,
#   'silver': 2,
#   'bronze': 3},
#  {'id': 466,
#   'name': 'Denmark',
#   'year': 1900,
#   'gold': 1,
#   'silver': 3,
#   'bronze': 2},
#  {'id': 467,
#   'name': 'Denmark',
#   'year': 1906,
#   'gold': 14,
#   'silver': 19,
#   'bronze': 1},
#  {'id': 468,
#   'name': 'Denmark',
#   'year': 1908,
#   'gold': 0,
#   'silver': 14,
#   'bronze': 3},
#  {'id': 469,
#   'name': 'Denmark',
#   'year': 1912,
#   'gold': 0,
#   'silver': 46,
#   'bronze': 28},
#  {'id': 470,
#   'name': 'Denmark',
#   'year': 1920,
#   'gold': 26,
#   'silver': 44,
#   'bronze': 1},
#  {'id': 471,
#   'name': 'Denmark',
#   'year': 1924,
#   'gold': 2,
#   'silver': 6,
#   'bronze': 3},
#  {'id': 472,
#   'name': 'Denmark',
#   'year': 1928,
#   'gold': 6,
#   'silver': 1,
#   'bronze': 4},
#  {'id': 473,
#   'name': 'Denmark',
#   'year': 1932,
#   'gold': 0,
#   'silver': 7,
#   'bronze': 4},
#  {'id': 474,
#   'name': 'Denmark',
#   'year': 1936,
#   'gold': 0,
#   'silver': 3,
#   'bronze': 3},
#  {'id': 475,
#   'name': 'Denmark',
#   'year': 1948,
#   'gold': 7,
#   'silver': 17,
#   'bronze': 24},
#  {'id': 476,
#   'name': 'Denmark',
#   'year': 1952,
#   'gold': 3,
#   'silver': 1,
#   'bronze': 5},
#  {'id': 477,
#   'name': 'Denmark',
#   'year': 1956,
#   'gold': 1,
#   'silver': 1,
#   'bronze': 1},
#  {'id': 478,
#   'name': 'Denmark',
#   'year': 1960,
#   'gold': 2,
#   'silver': 12,
#   'bronze': 4},
#  {'id': 479,
#   'name': 'Denmark',
#   'year': 1964,
#   'gold': 4,
#   'silver': 1,
#   'bronze': 4},
#  {'id': 480,
#   'name': 'Denmark',
#   'year': 1968,
#   'gold': 5,
#   'silver': 6,
#   'bronze': 6},
#  {'id': 481,
#   'name': 'Denmark',
#   'year': 1972,
#   'gold': 1,
#   'silver': 0,
#   'bronze': 0},
#  {'id': 482,
#   'name': 'Denmark',
#   'year': 1976,
#   'gold': 3,
#   'silver': 0,
#   'bronze': 5},
#  {'id': 483,
#   'name': 'Denmark',
#   'year': 1980,
#   'gold': 4,
#   'silver': 2,
#   'bronze': 2},
#  {'id': 484,
#   'name': 'Denmark',
#   'year': 1984,
#   'gold': 0,
#   'silver': 3,
#   'bronze': 10},
#  {'id': 485,
#   'name': 'Denmark',
#   'year': 1988,
#   'gold': 3,
#   'silver': 1,
#   'bronze': 3},
#  {'id': 486,
#   'name': 'Denmark',
#   'year': 1992,
#   'gold': 3,
#   'silver': 2,
#   'bronze': 9},
#  {'id': 487,
#   'name': 'Denmark',
#   'year': 1996,
#   'gold': 21,
#   'silver': 1,
#   'bronze': 1},
#  {'id': 488,
#   'name': 'Denmark',
#   'year': 1998,
#   'gold': 0,
#   'silver': 5,
#   'bronze': 0},
#  {'id': 489,
#   'name': 'Denmark',
#   'year': 2000,
#   'gold': 18,
#   'silver': 3,
#   'bronze': 4},
#  {'id': 490,
#   'name': 'Denmark',
#   'year': 2004,
#   'gold': 19,
#   'silver': 1,
#   'bronze': 7},
#  {'id': 491,
#   'name': 'Denmark',
#   'year': 2008,
#   'gold': 6,
#   'silver': 7,
#   'bronze': 3},
#  {'id': 492,
#   'name': 'Denmark',
#   'year': 2012,
#   'gold': 3,
#   'silver': 5,
#   'bronze': 6},
#  {'id': 493,
#   'name': 'Denmark',
#   'year': 2016,
#   'gold': 15,
#   'silver': 10,
#   'bronze': 16},
#  {'id': 494,
#   'name': 'Denmark-1',
#   'year': 2012,
#   'gold': 0,
#   'silver': 0,
#   'bronze': 2},
#  {'id': 495,
#   'name': 'Denmark-2',
#   'year': 2004,
#   'gold': 0,
#   'silver': 0,
#   'bronze': 2},
#  {'id': 496,
#   'name': 'Denmark/Sweden',
#   'year': 1900,
#   'gold': 6,
#   'silver': 0,
#   'bronze': 0},
#  {'id': 497,
#   'name': 'Deutscher Schwimm Verband Berlin',
#   'year': 1900,
#   'gold': 4,
#   'silver': 0,
#   'bronze': 0},
#  {'id': 498,
#   'name': 'Devon and Somerset Wanderers',
#   'year': 1900,
#   'gold': 12,
#   'silver': 0,
#   'bronze': 0},
# ...
#   'bronze': 3},
#  {'id': 831,
#   'name': 'Hollandia',
#   'year': 1928,
#   'gold': 0,
#   'silver': 6,
#   'bronze': 0},
#  {'id': 832,
#   'name': 'Hong Kong',
#   'year': 1996,
#   'gold': 1,
#   'silver': 0,
#   'bronze': 0},
#  {'id': 833,
#   'name': 'Hong Kong',
#   'year': 2012,
#   'gold': 0,
#   'silver': 0,
#   'bronze': 1},
#  {'id': 834,
#   'name': 'Hong Kong-2',
#   'year': 2004,
#   'gold': 0,
#   'silver': 2,
#   'bronze': 0},
#  {'id': 835,
#   'name': 'Humbug V',
#   'year': 1964,
#   'gold': 0,
#   'silver': 0,
#   'bronze': 2},
#  {'id': 836,
#   'name': 'Hungary',
#   'year': 1896,
#   'gold': 2,
#   'silver': 1,
#   'bronze': 3},
#  {'id': 837,
#   'name': 'Hungary',
#   'year': 1900,
#   'gold': 1,
#   'silver': 2,
#   'bronze': 2},
#  {'id': 838,
#   'name': 'Hungary',
#   'year': 1904,
#   'gold': 2,
#   'silver': 1,
#   'bronze': 1},
#  {'id': 839,
#   'name': 'Hungary',
#   'year': 1906,
#   'gold': 5,
#   'silver': 5,
#   'bronze': 3},
#  {'id': 840,
#   'name': 'Hungary',
#   'year': 1908,
#   'gold': 7,
#   'silver': 7,
#   'bronze': 6},
#  {'id': 841,
#   'name': 'Hungary',
#   'year': 1912,
#   'gold': 10,
#   'silver': 17,
#   'bronze': 3},
#  {'id': 842,
#   'name': 'Hungary',
#   'year': 1924,
#   'gold': 2,
#   'silver': 12,
#   'bronze': 8},
#  {'id': 843,
#   'name': 'Hungary',
#   'year': 1928,
#   'gold': 10,
#   'silver': 11,
#   'bronze': 0},
#  {'id': 844,
#   'name': 'Hungary',
#   'year': 1932,
#   'gold': 20,
#   'silver': 5,
#   'bronze': 8},
#  {'id': 845,
#   'name': 'Hungary',
#   'year': 1936,
#   'gold': 25,
#   'silver': 1,
#   'bronze': 15},
#  {'id': 846,
#   'name': 'Hungary',
#   'year': 1948,
#   'gold': 15,
#   'silver': 25,
#   'bronze': 22},
#  {'id': 847,
#   'name': 'Hungary',
#   'year': 1952,
#   'gold': 53,
#   'silver': 17,
#   'bronze': 32},
#  {'id': 848,
#   'name': 'Hungary',
#   'year': 1956,
#   'gold': 30,
#   'silver': 20,
#   'bronze': 16},
#  {'id': 849,
#   'name': 'Hungary',
#   'year': 1960,
#   'gold': 13,
#   'silver': 16,
#   'bronze': 37},
#  {'id': 850,
#   'name': 'Hungary',
#   'year': 1964,
#   'gold': 42,
#   'silver': 7,
#   'bronze': 7},
#  {'id': 851,
#   'name': 'Hungary',
#   'year': 1968,
#   'gold': 32,
#   'silver': 20,
#   'bronze': 29},
#  {'id': 852,
#   'name': 'Hungary',
#   'year': 1972,
#   'gold': 10,
#   'silver': 46,
#   'bronze': 25},
#  {'id': 853,
#   'name': 'Hungary',
#   'year': 1976,
#   'gold': 14,
#   'silver': 6,
#   'bronze': 35},
#  {'id': 854,
#   'name': 'Hungary',
#   'year': 1980,
#   'gold': 8,
#   'silver': 15,
#   'bronze': 40},
#  {'id': 855,
#   'name': 'Hungary',
#   'year': 1988,
#   'gold': 20,
#   'silver': 9,
#   'bronze': 15},
#  {'id': 856,
#   'name': 'Hungary',
#   'year': 1992,
#   'gold': 14,
#   'silver': 23,
#   'bronze': 8},
#  {'id': 857,
#   'name': 'Hungary',
#   'year': 1996,
#   'gold': 8,
#   'silver': 9,
#   'bronze': 26},
#  {'id': 858,
#   'name': 'Hungary',
#   'year': 2000,
#   'gold': 25,
#   'silver': 24,
#   'bronze': 4},
#  {'id': 859,
#   'name': 'Hungary',
#   'year': 2004,
#   'gold': 24,
#   'silver': 12,
#   'bronze': 4},
#  {'id': 860,
#   'name': 'Hungary',
#   'year': 2008,
#   'gold': 16,
#   'silver': 8,
#   'bronze': 3},
#  {'id': 861,
#   'name': 'Hungary',
#   'year': 2012,
#   'gold': 12,
#   'silver': 8,
#   'bronze': 6},
#  {'id': 862,
#   'name': 'Hungary',
#   'year': 2016,
#   'gold': 12,
#   'silver': 3,
#   'bronze': 7},
#  {'id': 863,
#   'name': 'Hungary-1',
#   'year': 1932,
#   'gold': 0,
#   'silver': 0,
#   'bronze': 2},
#  {'id': 864,
#   'name': 'Hungary-1',
#   'year': 1936,
#   'gold': 0,
#   'silver': 0,
#   'bronze': 2},
#  {'id': 865,
#   'name': 'Hungary-1',
#   'year': 1948,
#   'gold': 0,
#   'silver': 2,
#   'bronze': 0},
#  {'id': 866,
#   'name': 'Hungary-1',
#   'year': 1952,
#   'gold': 0,
#   'silver': 0,
#   'bronze': 2},
#  {'id': 867,
#   'name': 'Hurlingham-2',
#   'year': 1908,
#   'gold': 0,
#   'silver': 4,
#   'bronze': 0},
#  {'id': 868,
#   'name': 'Iceland',
#   'year': 1956,
#   'gold': 0,
#   'silver': 1,
#   'bronze': 0},
#  {'id': 869,
#   'name': 'Iceland',
#   'year': 1984,
#   'gold': 0,
#   'silver': 0,
#   'bronze': 1},
#  {'id': 870,
#   'name': 'Iceland',
#   'year': 2000,
#   'gold': 0,
#   'silver': 0,
#   'bronze': 1},
#  {'id': 871,
#   'name': 'Iceland',
#   'year': 2008,
#   'gold': 0,
#   'silver': 14,
#   'bronze': 0},
#  {'id': 872,
#   'name': 'Independent Rowing Club-3',
#   'year': 1904,
#   'gold': 0,
#   'silver': 0,
#   'bronze': 2},
#  {'id': 873,
#   'name': 'India',
#   'year': 1900,
#   'gold': 0,
#   'silver': 2,
#   'bronze': 0},
#  {'id': 874,
#   'name': 'India',
#   'year': 1924,
#   'gold': 7,
#   'silver': 0,
#   'bronze': 0},
#  {'id': 875,
#   'name': 'India',
#   'year': 1928,
#   'gold': 14,
#   'silver': 0,
#   'bronze': 0},
#  {'id': 876,
#   'name': 'India',
#   'year': 1932,
#   'gold': 15,
#   'silver': 0,
#   'bronze': 0},
#  {'id': 877,
#   'name': 'India',
#   'year': 1936,
#   'gold': 19,
#   'silver': 0,
#   'bronze': 0},
#  {'id': 878,
#   'name': 'India',
#   'year': 1948,
#   'gold': 20,
#   'silver': 0,
#   'bronze': 0},
#  {'id': 879,
#   'name': 'India',
#   'year': 1952,
#   'gold': 14,
#   'silver': 0,
#   'bronze': 1},
#  {'id': 880,
#   'name': 'India',
#   'year': 1956,
#   'gold': 17,
#   'silver': 0,
#   'bronze': 0},
#  {'id': 881,
#   'name': 'India',
#   'year': 1960,
#   'gold': 0,
#   'silver': 13,
#   'bronze': 0},
#  {'id': 882,
#   'name': 'India',
#   'year': 1964,
#   'gold': 15,
#   'silver': 0,
#   'bronze': 0},
#  {'id': 883,
#   'name': 'India',
#   'year': 1968,
#   'gold': 0,
#   'silver': 0,
#   'bronze': 16},
#  {'id': 884,
#   'name': 'India',
#   'year': 1972,
#   'gold': 0,
#   'silver': 0,
#   'bronze': 14},
#  {'id': 885,
#   'name': 'India',
#   'year': 1980,
#   'gold': 16,
#   'silver': 0,
#   'bronze': 0},
#  {'id': 886,
#   'name': 'India',
#   'year': 1996,
#   'gold': 0,
#   'silver': 0,
#   'bronze': 1},
#  {'id': 887,
#   'name': 'India',
#   'year': 2000,
#   'gold': 0,
#   'silver': 0,
#   'bronze': 1},
#  {'id': 888,
#   'name': 'India',
#   'year': 2004,
#   'gold': 0,
#   'silver': 1,
#   'bronze': 0},
#  {'id': 889,
#   'name': 'India',
#   'year': 2008,
#   'gold': 1,
#   'silver': 0,
#   'bronze': 2},
#  {'id': 890,
#   'name': 'India',
#   'year': 2012,
#   'gold': 0,
#   'silver': 2,
#   'bronze': 4},
#  {'id': 891,
#   'name': 'India',
#   'year': 2016,
#   'gold': 0,
#   'silver': 1,
#   'bronze': 1},
#  {'id': 892,
#   'name': 'Individual Olympic Athletes',
#   'year': 1992,
#   'gold': 0,
#   'silver': 1,
#   'bronze': 2},
#  {'id': 893,
#   'name': 'Individual Olympic Athletes',
#   'year': 2016,
#   'gold': 1,
#   'silver': 0,
#   'bronze': 1},
#  {'id': 894,
#   'name': 'Indonesia',
#   'year': 1988,
#   'gold': 0,
#   'silver': 3,
#   'bronze': 0},
#  {'id': 895,
#   'name': 'Indonesia',
#   'year': 1992,
#   'gold': 2,
#   'silver': 1,
#   'bronze': 1},
#  {'id': 896,
#   'name': 'Indonesia',
#   'year': 1996,
#   'gold': 2,
#   'silver': 1,
#   'bronze': 1},
#  {'id': 897,
#   'name': 'Indonesia',
#   'year': 2000,
#   'gold': 2,
#   'silver': 2,
#   'bronze': 2},
#  {'id': 898,
#   'name': 'Indonesia',
#   'year': 2004,
#   'gold': 1,
#   'silver': 1,
#   'bronze': 1},
#  {'id': 899,
#   'name': 'Indonesia',
#   'year': 2008,
#   'gold': 0,
#   'silver': 0,
#   'bronze': 3},
#  {'id': 900,
#   'name': 'Indonesia',
#   'year': 2012,
#   'gold': 0,
#   'silver': 1,
#   'bronze': 1},
#  {'id': 901,
#   'name': 'Indonesia',
#   'year': 2016,
#   'gold': 0,
#   'silver': 2,
#   'bronze': 0},
#  {'id': 902,
#   'name': 'Indonesia-1',
#   'year': 1992,
#   'gold': 0,
#   'silver': 2,
#   'bronze': 0},
#  {'id': 903,
#   'name': 'Indonesia-1',
#   'year': 1996,
#   'gold': 0,
#   'silver': 0,
#   'bronze': 2},
#  {'id': 904,
#   'name': 'Indonesia-1',
#   'year': 2000,
#   'gold': 0,
#   'silver': 2,
#   'bronze': 0},
#  {'id': 905,
#   'name': 'Indonesia-1',
#   'year': 2004,
#   'gold': 0,
#   'silver': 0,
#   'bronze': 2},
#  {'id': 906,
#   'name': 'Indonesia-1',
#   'year': 2008,
#   'gold': 2,
#   'silver': 2,
#   'bronze': 0},
#  {'id': 907,
#   'name': 'Indonesia-1',
#   'year': 2016,
#   'gold': 2,
#   'silver': 0,
#   'bronze': 0},
#  {'id': 908,
#   'name': 'Iran',
#   'year': 1948,
#   'gold': 0,
#   'silver': 0,
#   'bronze': 1},
#  {'id': 909,
#   'name': 'Iran',
#   'year': 1952,
#   'gold': 0,
#   'silver': 3,
#   'bronze': 4},
#  {'id': 910,
#   'name': 'Iran',
#   'year': 1956,
#   'gold': 2,
#   'silver': 2,
#   'bronze': 1},
#  {'id': 911,
#   'name': 'Iran',
#   'year': 1960,
#   'gold': 0,
#   'silver': 1,
#   'bronze': 3},
#  {'id': 912,
#   'name': 'Iran',
#   'year': 1964,
#   'gold': 0,
#   'silver': 0,
#   'bronze': 2},
#  {'id': 913,
#   'name': 'Iran',
#   'year': 1968,
#   'gold': 2,
#   'silver': 1,
#   'bronze': 2},
#  {'id': 914,
#   'name': 'Iran',
#   'year': 1972,
#   'gold': 0,
#   'silver': 2,
#   'bronze': 1},
#  {'id': 915,
#   'name': 'Iran',
#   'year': 1976,
#   'gold': 0,
#   'silver': 1,
#   'bronze': 1},
#  {'id': 916,
#   'name': 'Iran',
#   'year': 1988,
#   'gold': 0,
#   'silver': 1,
#   'bronze': 0},
#  {'id': 917,
#   'name': 'Iran',
#   'year': 1992,
#   'gold': 0,
#   'silver': 1,
#   'bronze': 2},
#  {'id': 918,
#   'name': 'Iran',
#   'year': 1996,
#   'gold': 1,
#   'silver': 1,
#   'bronze': 1},
#  {'id': 919,
#   'name': 'Iran',
#   'year': 2000,
#   'gold': 3,
#   'silver': 0,
#   'bronze': 1},
#  {'id': 920,
#   'name': 'Iran',
#   'year': 2004,
#   'gold': 2,
#   'silver': 2,
#   'bronze': 2},
#  {'id': 921,
#   'name': 'Iran',
#   'year': 2008,
#   'gold': 1,
#   'silver': 0,
#   'bronze': 1},
#  {'id': 922,
#   'name': 'Iran',
#   'year': 2012,
#   'gold': 4,
#   'silver': 5,
#   'bronze': 3},
#  {'id': 923,
#   'name': 'Iran',
#   'year': 2016,
#   'gold': 3,
#   'silver': 1,
#   'bronze': 4},
#  {'id': 924,
#   'name': 'Iraq',
#   'year': 1960,
#   'gold': 0,
#   'silver': 0,
#   'bronze': 1},
#  {'id': 925,
#   'name': 'Ireland',
#   'year': 1924,
#   'gold': 0,
#   'silver': 1,
#   'bronze': 1},
#  {'id': 926,
#   'name': 'Ireland',
#   'year': 1928,
#   'gold': 1,
#   'silver': 0,
#   'bronze': 0},
#  {'id': 927,
#   'name': 'Ireland',
#   'year': 1932,
#   'gold': 2,
#   'silver': 0,
#   'bronze': 0},
#  {'id': 928,
#   'name': 'Ireland',
#   'year': 1948,
#   'gold': 0,
#   'silver': 0,
#   'bronze': 1},
#  {'id': 929,
#   'name': 'Ireland',
#   'year': 1952,
#   'gold': 0,
#   'silver': 1,
#   'bronze': 0},
#  {'id': 930,
#   'name': 'Ireland',
#   'year': 1956,
#   'gold': 1,
#   'silver': 1,
#   'bronze': 3},
#  {'id': 931,
#   'name': 'Ireland',
#   'year': 1964,
#   'gold': 0,
#   'silver': 0,
#   'bronze': 1},
#  {'id': 932,
#   'name': 'Ireland',
#   'year': 1980,
#   'gold': 0,
#   'silver': 2,
#   'bronze': 1},
#  {'id': 933,
#   'name': 'Ireland',
#   'year': 1984,
#   'gold': 0,
#   'silver': 1,
#   'bronze': 0},
#  {'id': 934,
#   'name': 'Ireland',
#   'year': 1992,
#   'gold': 1,
#   'silver': 1,
#   'bronze': 0},
#  {'id': 935,
#   'name': 'Ireland',
#   'year': 1996,
#   'gold': 3,
#   'silver': 0,
#   'bronze': 1},
#  {'id': 936,
#   'name': 'Ireland',
#   'year': 2000,
#   'gold': 0,
#   'silver': 1,
#   'bronze': 0},
#  {'id': 937,
#   'name': 'Ireland',
#   'year': 2008,
#   'gold': 0,
#   'silver': 1,
#   'bronze': 2},
#  {'id': 938,
#   'name': 'Ireland',
#   'year': 2012,
#   'gold': 1,
#   'silver': 1,
#   'bronze': 3},
#  {'id': 939,
#   'name': 'Ireland',
#   'year': 2016,
#   'gold': 0,
#   'silver': 3,
#   'bronze': 0},
#  {'id': 940,
#   'name': 'Ireland-2',
#   'year': 1908,
#   'gold': 0,
#   'silver': 12,
#   'bronze': 0},
#  {'id': 941,
#   'name': 'Ireland-3',
#   'year': 1908,
#   'gold': 0,
#   'silver': 4,
#   'bronze': 0},
#  {'id': 942,
#   'name': 'Irene',
#   'year': 1920,
#   'gold': 5,
#   'silver': 0,
#   'bronze': 0},
#  {'id': 943,
#   'name': 'Israel',
#   'year': 1992,
#   'gold': 0,
#   'silver': 1,
#   'bronze': 1},
#  {'id': 944,
#   'name': 'Israel',
#   'year': 1996,
#   'gold': 0,
#   'silver': 0,
#   'bronze': 1},
#  {'id': 945,
#   'name': 'Israel',
#   'year': 2000,
#   'gold': 0,
#   'silver': 0,
#   'bronze': 1},
#  {'id': 946,
#   'name': 'Israel',
#   'year': 2004,
#   'gold': 1,
#   'silver': 0,
#   'bronze': 1},
#  {'id': 947,
#   'name': 'Israel',
#   'year': 2008,
#   'gold': 0,
#   'silver': 0,
#   'bronze': 1},
#  {'id': 948,
#   'name': 'Israel',
#   'year': 2016,
#   'gold': 0,
#   'silver': 0,
#   'bronze': 2},
#  {'id': 949,
#   'name': 'Italia',
#   'year': 1936,
#   'gold': 6,
#   'silver': 0,
#   'bronze': 0},
#  {'id': 950,
#   'name': 'Italy',
#   'year': 1900,
#   'gold': 3,
#   'silver': 2,
#   'bronze': 0},
#  {'id': 951,
#   'name': 'Italy',
#   'year': 1906,
#   'gold': 3,
#   'silver': 5,
#   'bronze': 1},
#  {'id': 952,
#   'name': 'Italy',
#   'year': 1908,
#   'gold': 2,
#   'silver': 6,
#   'bronze': 0},
#  {'id': 953,
#   'name': 'Italy',
#   'year': 1912,
#   'gold': 22,
#   'silver': 1,
#   'bronze': 2},
#  {'id': 954,
#   'name': 'Italy',
#   'year': 1920,
#   'gold': 67,
#   'silver': 9,
#   'bronze': 8},
#  {'id': 955,
#   'name': 'Italy',
#   'year': 1924,
#   'gold': 25,
#   'silver': 5,
#   'bronze': 21},
#  {'id': 956,
#   'name': 'Italy',
#   'year': 1928,
#   'gold': 24,
#   'silver': 22,
#   'bronze': 26},
#  {'id': 957,
#   'name': 'Italy',
#   'year': 1932,
#   'gold': 21,
#   'silver': 38,
#   'bronze': 18},
#  {'id': 958,
#   'name': 'Italy',
#   'year': 1936,
#   'gold': 31,
#   'silver': 34,
#   'bronze': 5},
#  {'id': 959,
#   'name': 'Italy',
#   'year': 1948,
#   'gold': 22,
#   'silver': 32,
#   'bronze': 14},
#  {'id': 960,
#   'name': 'Italy',
#   'year': 1952,
#   'gold': 16,
#   'silver': 22,
#   'bronze': 16},
#  {'id': 961,
#   'name': 'Italy',
#   'year': 1956,
#   'gold': 26,
#   'silver': 9,
#   'bronze': 10},
#  {'id': 962,
#   'name': 'Italy',
#   'year': 1960,
#   'gold': 36,
#   'silver': 18,
#   'bronze': 32},
#  {'id': 963,
#   'name': 'Italy',
#   'year': 1964,
#   'gold': 14,
#   'silver': 28,
#   'bronze': 9},
#  {'id': 964,
#   'name': 'Italy',
#   'year': 1968,
#   'gold': 7,
#   'silver': 8,
#   'bronze': 20},
#  {'id': 965,
#   'name': 'Italy',
#   'year': 1972,
#   'gold': 10,
#   'silver': 4,
#   'bronze': 14},
#  {'id': 966,
#   'name': 'Italy',
#   'year': 1976,
#   'gold': 3,
#   'silver': 27,
#   'bronze': 5},
#  {'id': 967,
#   'name': 'Italy',
#   'year': 1980,
#   'gold': 8,
#   'silver': 22,
#   'bronze': 8},
#  {'id': 968,
#   'name': 'Italy',
#   'year': 1984,
#   'gold': 31,
#   'silver': 6,
#   'bronze': 28},
#  {'id': 969,
#   'name': 'Italy',
#   'year': 1988,
#   'gold': 13,
#   'silver': 11,
#   'bronze': 13},
#  {'id': 970,
#   'name': 'Italy',
#   'year': 1992,
#   'gold': 25,
#   'silver': 19,
#   'bronze': 20},
#  {'id': 971,
#   'name': 'Italy',
#   'year': 1994,
#   'gold': 12,
#   'silver': 4,
#   'bronze': 10},
#  {'id': 972,
#   'name': 'Italy',
#   'year': 1996,
#   'gold': 19,
#   'silver': 24,
#   'bronze': 28},
#  {'id': 973,
#   'name': 'Italy',
#   'year': 1998,
#   'gold': 1,
#   'silver': 9,
#   'bronze': 5},
#  {'id': 974,
#   'name': 'Italy',
#   'year': 2000,
#   'gold': 22,
#   'silver': 14,
#   'bronze': 29},
#  {'id': 975,
#   'name': 'Italy',
#   'year': 2002,
#   'gold': 4,
#   'silver': 11,
#   'bronze': 4},
#  {'id': 976,
#   'name': 'Italy',
#   'year': 2004,
#   'gold': 24,
#   'silver': 41,
#   'bronze': 39},
#  {'id': 977,
#   'name': 'Italy',
#   'year': 2006,
#   'gold': 11,
#   'silver': 0,
#   'bronze': 10},
#  {'id': 978,
#   'name': 'Italy',
#   'year': 2008,
#   'gold': 8,
#   'silver': 14,
#   'bronze': 20},
#  {'id': 979,
#   'name': 'Italy',
#   'year': 2010,
#   'gold': 1,
#   'silver': 1,
#   'bronze': 3},
#  {'id': 980,
#   'name': 'Italy',
#   'year': 2012,
#   'gold': 16,
#   'silver': 22,
#   'bronze': 30},
#  {'id': 981,
#   'name': 'Italy',
#   'year': 2014,
#   'gold': 0,
#   'silver': 2,
#   'bronze': 12},
#  {'id': 982,
#   'name': 'Italy',
#   'year': 2016,
#   'gold': 8,
#   'silver': 38,
#   'bronze': 24},
#  {'id': 983,
#   'name': 'Italy-1',
#   'year': 1956,
#   'gold': 2,
#   'silver': 0,
#   'bronze': 0},
#  {'id': 984,
#   'name': 'Italy-1',
#   'year': 1964,
#   'gold': 0,
#   'silver': 0,
#   'bronze': 4},
#  {'id': 985,
#   'name': 'Italy-1',
#   'year': 1968,
#   'gold': 6,
#   'silver': 0,
#   'bronze': 0},
#  {'id': 986,
#   'name': 'Italy-1',
#   'year': 1972,
#   'gold': 2,
#   'silver': 4,
#   'bronze': 0},
#  {'id': 987,
#   'name': 'Italy-1',
#   'year': 1980,
#   'gold': 0,
#   'silver': 2,
#   'bronze': 0},
#  {'id': 988,
#   'name': 'Italy-1',
#   'year': 1992,
#   'gold': 0,
#   'silver': 0,
#   'bronze': 2},
#  {'id': 989,
#   'name': 'Italy-1',
#   'year': 1994,
#   'gold': 2,
#   'silver': 0,
#   'bronze': 2},
#  {'id': 990,
#   'name': 'Italy-1',
#   'year': 1998,
#   'gold': 2,
#   'silver': 0,
#   'bronze': 0},
#  {'id': 991,
#   'name': 'Italy-1',
#   'year': 2002,
#   'gold': 0,
#   'silver': 0,
#   'bronze': 2},
#  {'id': 992,
#   'name': 'Italy-1',
#   'year': 2006,
#   'gold': 0,
#   'silver': 0,
#   'bronze': 4},
#  {'id': 993,
#   'name': 'Italy-1',
#   'year': 2016,
#   'gold': 0,
#   'silver': 2,
#   'bronze': 0},
#  {'id': 994,
#   'name': 'Italy-2',
#   'year': 1956,
#   'gold': 0,
#   'silver': 6,
#   'bronze': 0},
#  {'id': 995,
#   'name': 'Italy-2',
#   'year': 1964,
#   'gold': 0,
#   'silver': 2,
#   'bronze': 4},
#  {'id': 996,
#   'name': 'Italy-2',
#   'year': 1994,
#   'gold': 0,
#   'silver': 2,
#   'bronze': 0},
#  {'id': 997,
#   'name': 'Jamaica',
#   'year': 1948,
#   'gold': 1,
#   'silver': 2,
#   'bronze': 0},
#  {'id': 998,
#   'name': 'Jamaica',
#   'year': 1952,
#   'gold': 5,
#   'silver': 3,
#   'bronze': 0},
#  {'id': 999,
#   'name': 'Jamaica',
#   'year': 1968,
#   'gold': 0,
#   'silver': 1,
#   'bronze': 0},
#  ...]

# %%
finalPull.jsonify
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-95d70420845c> in <module>
# ----> 1 finalPull.jsonify
#
# AttributeError: 'list' object has no attribute 'jsonify'

# %%
jsonify(finalPull)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-01a862212171> in <module>
# ----> 1 jsonify(finalPull)
#
# NameError: name 'jsonify' is not defined
